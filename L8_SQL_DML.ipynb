# %% [markdown]
# <img src="https://github.com/christopherhuntley/BUAN6510/blob/master/img/Dolan.png?raw=true" width="180px" align="right">
#
# # **BUAN 6510**
# # **Lesson 8: SQL DML**
# _Where SQL takes action_
#
# ## **Learning Objectives**
# ### **Theory / Be able to explain ...**
# - ACID transactions
# - SQL's role in the data ETL process
# - The various SQL DML statements
# - How transaction controls can be used for multi-step database operations
# - The basics of cloud-based RDBMS hosting
#
# ### **Skills / Know how to ...**
# - Create normalized tables from denormalized datasets
# - Use SQL DML for basic CRUD operations
# - Avoid common load order issues
# - Use `CASE` expressions to implement complex conversion logic
#
# --------
# ## **LESSON 8 HIGHLIGHTS**

# %%
#@title Run this cell if video does not appear
# %%html
<div style="max-width:1000px">
  <div style="position: relative;padding-bottom: 56.25%;height: 0;">
    <iframe style="position: absolute;top: 0;left: 0;width: 100%;height: 100%;" rel="0" modestbranding="1"  src="https://www.youtube.com/embed/joDkI1ttf9o" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
  </div>
</div>
# Out:
# <div style="max-width:1000px">
#   <div style="position: relative;padding-bottom: 56.25%;height: 0;">
#     <iframe style="position: absolute;top: 0;left: 0;width: 100%;height: 100%;" rel="0" modestbranding="1"  src="https://www.youtube.com/embed/joDkI1ttf9o" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
#   </div>
# </div>

# %% [markdown]
# ---
# ## **BIG PICTURE: CRUD on ACID**
# The general theme of this lesson is about transactional processing that puts, alters, and deletes data in databases. In past lessons we discussed the four basic CRUD actions in the abstract. Now we will get into the nitty gritty details, or at least the ones that can be addressed with SQL.
#
# In principle we'd like the data in our database to survive IT armageddon where the power shuts down with no notice, the database is in the middle of a lengthy operation, and the consequences of failure are catastrophic. Then perhaps we can begin to count on it being there when we need it.
#
# The gold standard for robustness in the face of catastrophic failure is ACID, four properties that together go as far as possible to keep our data safe:
# - **Atomicity.** Lengthy transactions with lots of steps are treated as one unit. If any step fails then we can roll it back to the beginning, as if it never happened.
# - **Consistency.** We never want the database to be in an unexpected or unrecoverable state. If given data operations in any given order the result is always the same. There is no ambiguity or uncertainty introduced by the system itself.
# - **Isolation.** Just like people, databases often have to multitask, processing several transactions at once. Ideally, we want to keep failure of any transaction from causing failure of another. They should be running as independently as possible, *especially* when failure risk is high.
# - **Durability.** Once data has been committed by a transaction, it should persist until another transaction alters it.
#
# If you think about each of these things, you will realize just how fragile most software really is.
# - How far back in time does the "undo" on your word processor allow you to go back? If everything you have written since yesterday afternoon was garbage, could you recover it *even if you never saved it anywhere?*
# - If your computer crashed while it was halfway through saving the latest draft of your senior thesis, would the file be recoverable? Would you lose half your work?
# - If you and a classmate are editing the same Google doc and your partner falls asleep at the keyboard, typing an infinite string of J characters ..., can you regain control before everything is destroyed? Or do you have to start over with a new doc?
# - If you start recording a workout on your smart watch but then forget to end the workout before all of the power is drained from your battery, does any data get lost?
#
# ACID is how we prevent all of these things from blowing up your data.
#
# Okay, so where do you get ACID? From any modern relational database product. Even the most primitive ones like SQLite or MS Access are better than any other tool for keeping your data safe. They are CRUD on ACID, and that's a good thing.

# %% [markdown]
# ---
# ## **ETL = Extract $\rightarrow$ Transform $\rightarrow$ Load**
#
# While it is certainly wonderful and makes the analyst's life much easier if data was collected expressly for their use, the typical case is not so great. Data can come from anywhere and may require significant scrubbing before it can be trusted. In some cases, there may be multiple data sources, with somewhat incompatible data to be merged into a coherent dataset.
#
# The general process of working with such *dirty* data is called ETL:
# - **Extract** data from the original sources.
# - **Transform** and integrate it to fit the new purpose.
# - **Load it** into a central data repository that will protect the data from corruption.
#
# While there are certainly other tools for this purpose, SQL is a great place to start:
# - Modern relational databases include utilities for working with data in various formats.
# - SQL includes plenty of functions for transforming data from one data type to another *plus* the power of SQL queries to bring it all together into a useful form. **If SQL is not not enough, then use another tool as well.** SQL is already compatible with just about every programming language on earth. It has serious first mover advantage from decades of heavy use.
# - When you are done, the data can reside safely in a database with the guarantees of full ACID compliance.
#
# After reviewing the syntax and function of SQL `INSERT`, `UPDATE`, and `DELETE` statements, we will consider a few special cases that put ACID principles to the test.

# %% [markdown]
# ---
# ## **SQL `INSERT` Statements**
# We use `INSERT` statements to add rows to a table. There are two basic forms:
# - Adding new data (values) to the database
# - Addind table data extracted (selected) from another table
#
# ### **`INSERT INTO ... VALUES`**
#
# ```sql
# INSERT INTO tablename ( columnlist ) VALUES
#   ( valuelist );
# ```
#
# - `columnlist` and `valuelist` are comma-separated lists of column names and literal values. The two lists have exactly the same number of items, with the first column corresponding to the first value, etc.
# - Any columns not included in the `columnlist` are not assigned a NULL value unless a `DEFAULT` value is specified.
# - If the table has a surrogate primary key, then generally we do not want to include the primary key column; the database will generate it for us.
# - When we say *literal values* in the `valuelist` we mean the values they would appear in a `WHERE` clause. It would be the value to the right of the `=` in a boolean expression.
# - The parentheses and trailing semicolon are not optional.
#
# We can insert multiple rows at a time as follows.
#
# ```sql
# INSERT INTO tablename ( columnlist ) VALUES
#   ( valuelist1 ),
#   ( valuelist2 ),
#   ...
#   ;
# ```
#
# - That's a list of `valuelist` items, one per row.
# - There is no comma just before the semicolon.
#
# For example, the following adds two new movies to the Movies Tonight database:
# ```sql
# INSERT INTO movies ( title, rating ) VALUES
#   ('Romeo and Juliet', 'PG-13'),
#   ('A Time to Kill','PG-13');
# ```
# Note that the `movieID` column was omitted because it is autogenerated by the database.
#
#
# ### `INSERT INTO ... SELECT`
# If the data is already in the database in some form, then we can use a `SELECT` query to  gather the data values prior to insertion.
#
# ```sql
# INSERT INTO tablename ( columnlist )
#   SELECT ...
#   ;
# ```
#
# - As with inserting literal values the columns returned by the `SELECT` query must correspond to the ones in the `columnlist`
# - The actual names of the columns returned by the `SELECT` query do not matter, though the data types should be compatible with what is already defined in the table.
#
# Another movies example, this time using data [imported from IMDB](https://www.imdb.com/interfaces/):
#
# ```sql
# INSERT INTO movies ( title )
#   SELECT primaryTitle
#   FROM imdb_title_basics_import
#   WHERE startYear = "1996"
# ```
#
# - Since IMDB does not provide US movie ratings in its public data dumps the `ratings` column was omitted from the `columnlist`. That also means that the `ratings` column has to allow null values. Otherwise the insertion will fail.
# - If we want to keep track of the `tconst` movie identifier used by IMDB then we will have to add another column to the `movies` table.

# %% [markdown]
# ---
# ## **SQL `UPDATE` Statements**
#
# SQL `UPDATE` statements set specific column values on selected rows.
#
# ```sql
# UPDATE tablename
# SET
#   column1 = newvalue1,
#   column2 = newvalue2,
#   ...
# WHERE ...
# ;
# ```
# - Only the columns that are being updated need to be included.
# - The `WHERE` clause works just like in a `SELECT` query.
# - A new value can be any expression that returns a scalar value. That includes subqueries.
# - It is possible to use joins to update several tables at once. However, that is fairly new to the SQL standards and not likely to work in older (legacy) databases. It won't work n MySQL 5.7, for example, but it does work in MySQL 8.0. The workaround is to use subqueries (with joins) instead.
#
# Here we are updating the *Romeo + Juliet* movie title to its proper name.
#
# ```sql
# UPDATE movies
# SET
#   title = 'Romeo + Juliet'
# WHERE
#   movieID = 24;
# ```

# %% [markdown]
# ---
# ## **SQL `DELETE` Statements**
#
# Deleting rows is about as easy as it gets.
#
# ```sql
# DELETE FROM tablename
# WHERE ...
# ```
#
# - There is no need to specify columns.
# - If the `WHERE` clause is omitted then *every* row is deleted.
# - We can delete from multiple tables at a time with slightly altered syntax. However, it is not universally supported.

# %% [markdown]
# ---
# ## **Load Order and Transactions**
# Maintaining referential integrity is a continual process. The DBMS is always on the lookout for integrity violations. Each query is treated as an *atomic transaction* that can be undone (rolled back) if it does not complete sucessfully. Thus, is an update query sets a foreign key to an impossible value or nullified something that can't be null, then the database will immediately complain and return the database state to whatever it was before the query.
#
# While that is a very reasonable and safe way to approach data integrity, it has some implciations for how and when we load data into a given table. We will first consider cases where **table load order** can be used to avoid referential integrity violations. Then we will consider cases where we have to go further, using custom transaction controls to force the database to do what we need it to.
#
# ### **Strongest First Loading**
# The vast majority of referential integrity problems can be prevented by taking care about the order in which we insert and delete records.
#
# Consider any parent-child relationship where the parent must exist before the child.
#
# The process to add a new child row is then:
# 1. If the parent doesn't exist then add the parent first.
# 2. Once the parent exists, then add the child.
#
# Deleting the parent can cause the opposite problem, as all children will need to be deleted before the parent. We can use `ON DELETE CASCADE` in the foreign key constraints to handle that automatically.
#
# When applied to a whole database the load order is strongest to weakest:
# 1. Load all the strong entities.
# 2. Load all weak entities that only depend on strng entities.
# 3. Load any entities that only rely on #1 and #2.
# 4. ...
#
# We will see this strategy in place with the Movies Tonight case a little further down.
#
# ### **Transaction Control**
#
# Sometimes just taking care with load order is not enough. For those cases we use transaction control.
#
# Consider the classic parent-child-grandchild case, where there is a whole hierarchy of entities to be saved at once. This might happen, for example, when saving a new customer, the customer's order invoice, and the invoice line items. Based on the Strongest to Weakest rule, we would save the parent (customer record), then the child (invoice), and then the grand children (line items).
#
# The SQL code might look something like this:
#
# ```sql
# INSERT INTO customers ...
# INSERT INTO invoices ...  -- MySQL: use LAST_INSERT_ID() function to get the new customer id
#                           -- SQLite: use LAST_INSERT_ROWID()
# INSERT INTO invoice_items ...
# ```
#
# However, what happens if there is a problem saving one of the grand children? Then the entire transaction should be voided, including the invoice and new customer record. Instead of deleting them one by one, we can use a transaction block instead:
#
# ```sql
#
# BEGIN;        -- Start a new Transaction
# INSERT INTO customers ...
# INSERT INTO invoices ...
# INSERT INTO invoice_items ...
# COMMIT;       -- Finalize the Transaction
# ```
#
# If the transaction fails before the `COMMIT` statement, then all changes made during the transaction are ignored. It's like it never happened.
#
# Generally, multistep transactions like this are packaged together as **stored procedures**. However, since creating stored procedures is more of a task for data engineers than data analysts, it is beyond the scope of this course.
#
# #### **Solving the Twinning Problem**
# Transaction control can be used to solve the mandatory twins issue from Lesson 6. Depending on the database vendor, there are two different approaches.
#
# The most common (and theoretically correct) approach is **deferred commit**, where specific foreign key checks are marked as *deferrable* if they are inside of a transaction block. The keys are then checked as part of the `COMMIT` at the end. [This is how it works in SQLite](https://www.sqlite.org/foreignkeys.html), for example.
#
# A more risky approach is to **explictly disable foreign key checks** during a given transaction block. In MySQL this looks like:
#
# ```sql
# BEGIN;
# SET foreign_key_checks = 0; -- disables FK checking
# ...
# SET foreign_key_checks = 1; -- reenables FK checking
# COMMIT;
# ```
#
# The risk here is that one might forget to the `SET foreign_key_checks = 1;` step just before the `COMMIT`.

# %% [markdown]
# ---
# ## **Movies Tonight, Part 4**
#
# We will finish off the Movies Tonight case by extracting, transforming, and loading the data from a single CSV file.
#
# ![ERD from Lesson 5](https://github.com/christopherhuntley/BUAN6510/raw/master/img/L6_MoviesTonight_v2.png)
#
# - `Artists(`**`artistID`**, `name)`
# - `Movies(`**`movieID`**, `title,rating)`
# - `Theaters(`**`theaterID`**, `name, location, phone)`
# - `Credits(`**`creditID`**, `credit_code`, <u>`movieID`</u>,<u>`artistID`</u>`)`
# - `Shows(`**`showID`**, `showtime`, <u>`movieID`</u>,<u>`theaterID`</u>`)`
#
# ### **Setup (Again)**
#
# The code below creates a folder in Google Drive for our SQLite database.

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Create the BUAN6510/data/MoviesTonight folder in Google Drive
from pathlib import Path
data_root = Path("./drive/My Drive/Colab Notebooks/BUAN6510")
if not data_root.exists():
  print(
      '''
      Warning! The folder '/Colab Notebooks/BUAN6510' could not be found in the connected Google Drive. 
      Please make 100% sure that both Colab and Chrome are set up use your @student.fairfield.edu account. 
      For now, a new folder with the correct path has been created in whatever Google Drive it found. 
      ''')
data_root = data_root / 'data' / 'MoviesTonight'
data_root.mkdir(parents=True, exist_ok=True)
# Out:
# Mounted at /content/drive

# %%
# %%bash
# ln -s drive/My\ Drive/Colab\ Notebooks/BUAN6510 buan6510

# %%
# Load %%sql magic
# %load_ext sql

# Standard Imports
import sqlite3
import pandas as pd

# Database connection
# %sql sqlite:///buan6510/data/MoviesTonight/MoviesTonight.db
# Out:
# 'Connected: @buan6510/data/MoviesTonight/MoviesTonight.db'

# %% [markdown]
# The database connection should reopen your database from Lesson 7. Now we just need to insert data.

# %% [markdown]
# ### **Importing from CSV**

# %%
# retrieve the DATASET.csv file
dataset_df = pd.read_csv('https://raw.githubusercontent.com/christopherhuntley/BUAN6510/master/data/MoviesTonight/DATASET.csv')
conn = sqlite3.connect('buan6510/data/MoviesTonight/MoviesTonight.db') 
dataset_df.to_sql('DATASET',conn,if_exists='replace',index=False)

# %%
# %%sql @buan6510/data/MoviesTonight/MoviesTonight.db
# SELECT * FROM DATASET LIMIT 10;
# Out:
# Done.
# [('Akarakian Theatres Moreno 4 Cinemas', 'The Intersection Of Alessandro + Perris Blvds, Moreno Valley', '(909) 485-2899', 'Associate, The', '4:20 PM', 'PG-13', 'A', 'Austin Pendleton'),
#  ('Akarakian Theatres Moreno 4 Cinemas', 'The Intersection Of Alessandro + Perris Blvds, Moreno Valley', '(909) 485-2899', 'Associate, The', '4:20 PM', 'PG-13', 'A', 'Bebe Neuwirth'),
#  ('Akarakian Theatres Moreno 4 Cinemas', 'The Intersection Of Alessandro + Perris Blvds, Moreno Valley', '(909) 485-2899', 'Associate, The', '4:20 PM', 'PG-13', 'A', 'Dianne Wiest'),
#  ('Akarakian Theatres Moreno 4 Cinemas', 'The Intersection Of Alessandro + Perris Blvds, Moreno Valley', '(909) 485-2899', 'Associate, The', '4:20 PM', 'PG-13', 'A', 'Eli Wallach'),
#  ('Akarakian Theatres Moreno 4 Cinemas', 'The Intersection Of Alessandro + Perris Blvds, Moreno Valley', '(909) 485-2899', 'Associate, The', '4:20 PM', 'PG-13', 'A', 'Kenny Kerr'),
#  ('Akarakian Theatres Moreno 4 Cinemas', 'The Intersection Of Alessandro + Perris Blvds, Moreno Valley', '(909) 485-2899', 'Associate, The', '4:20 PM', 'PG-13', 'A', 'Lainie Kazan'),
#  ('Akarakian Theatres Moreno 4 Cinemas', 'The Intersection Of Alessandro + Perris Blvds, Moreno Valley', '(909) 485-2899', 'Associate, The', '4:20 PM', 'PG-13', 'A', 'Tim Daly'),
#  ('Akarakian Theatres Moreno 4 Cinemas', 'The Intersection Of Alessandro + Perris Blvds, Moreno Valley', '(909) 485-2899', 'Associate, The', '4:20 PM', 'PG-13', 'A', 'Whoopi Goldberg'),
#  ('Akarakian Theatres Moreno 4 Cinemas', 'The Intersection Of Alessandro + Perris Blvds, Moreno Valley', '(909) 485-2899', 'Associate, The', '4:20 PM', 'PG-13', 'D', 'Donald Petrie'),
#  ('Akarakian Theatres Moreno 4 Cinemas', 'The Intersection Of Alessandro + Perris Blvds, Moreno Valley', '(909) 485-2899', 'Associate, The', '7:20 PM', 'PG-13', 'A', 'Austin Pendleton')]

# %% [markdown]
# ### **Populating the Strong Entity Tables**
# There are three tables without any foreign keys:
# - Theaters
# - Movies
# - Artists
#
# These can be created directly from the `DATASET` table. However, we won't do it all at once. **To be sure we know what will be inserted, always write the SELECT query first.** We'll do it in slow motion below but in real life you would just use one cell, rerunning with each step.

# %% [markdown]
# #### **The `theaters` Table**
#
# **Pass 1: `SELECT` ONLY**

# %%
# %%sql
# -- Select the data for the theaters table
# -- Note the use of DISTINCT here; very important
# -- There should be nine theaters with no duplicates
# -- SQLite handles the theaterID for us
# SELECT DISTINCT tname,location,phone
# FROM DATASET;
# Out:
#  * sqlite:///buan6510/data/MoviesTonight/MoviesTonight.db
# Done.
# [('Akarakian Theatres Moreno 4 Cinemas', 'The Intersection Of Alessandro + Perris Blvds, Moreno Valley', '(909) 485-2899'),
#  ('Cinema Star The Ultraplex 14', 'Mission Grove, Riverside', '(909) 342-2256'),
#  ('General Cinema Rancho 6', ' I-215 At Mt. Vernon S. At I-10, San Bernardino', '(714) 370-2085'),
#  ('Pacific Inland Center', ' Inland Center Mall, San Bernardino', '(714) 381-1611'),
#  ('SOCAL Canyon Crest Cinema', 'Central Avenue South Of 60 Freeway Near Ucr, Riverside', '(909) 682-6900'),
#  ('SOCAL Canyon Springs Cinema', 'East Of I-215 On 60 Freeway At Day Street Canyon, Moreno Valley', '(909) 782-0800'),
#  ('SOCAL Marketplace Cinema', 'University/mission Inn Exits East Of 91 Freeway On, Riverside', '(909) 682-4040'),
#  ('United Artists Riverside (Galleria) Tyler Mall', 'Riverside Fwy Tyler, Riverside', '(714) 689-802'),
#  ('United Artists Riverside Park Sierra', '3600 Park Sierra Dr., Riverside', '(909) 359-6995')]

# %% [markdown]
# **Pass 2: `INSERT` and test that it worked**

# %%
# %%sql
# -- Populating the theaters table
# -- make sure the table is empty
# DELETE FROM theaters;
#
# -- insert selected data
# INSERT INTO theaters (name,location,phone)
# SELECT DISTINCT tname,location,phone
# FROM DATASET;
# Out:
#  * sqlite:///buan6510/data/MoviesTonight/MoviesTonight.db
# Done.
# Done.
# []

# %%
# %%sql
# -- There are 9 theaters
# SELECT *
# FROM theaters;
# Out:
#  * sqlite:///buan6510/data/MoviesTonight/MoviesTonight.db
# Done.
# [(1, 'Akarakian Theatres Moreno 4 Cinemas', 'The Intersection Of Alessandro + Perris Blvds, Moreno Valley', '(909) 485-2899'),
#  (2, 'Cinema Star The Ultraplex 14', 'Mission Grove, Riverside', '(909) 342-2256'),
#  (3, 'General Cinema Rancho 6', ' I-215 At Mt. Vernon S. At I-10, San Bernardino', '(714) 370-2085'),
#  (4, 'Pacific Inland Center', ' Inland Center Mall, San Bernardino', '(714) 381-1611'),
#  (5, 'SOCAL Canyon Crest Cinema', 'Central Avenue South Of 60 Freeway Near Ucr, Riverside', '(909) 682-6900'),
#  (6, 'SOCAL Canyon Springs Cinema', 'East Of I-215 On 60 Freeway At Day Street Canyon, Moreno Valley', '(909) 782-0800'),
#  (7, 'SOCAL Marketplace Cinema', 'University/mission Inn Exits East Of 91 Freeway On, Riverside', '(909) 682-4040'),
#  (8, 'United Artists Riverside (Galleria) Tyler Mall', 'Riverside Fwy Tyler, Riverside', '(714) 689-802'),
#  (9, 'United Artists Riverside Park Sierra', '3600 Park Sierra Dr., Riverside', '(909) 359-6995')]

# %% [markdown]
# We can then repeat the process for the other two tables, shown here in one cell each. Again, even here the code was written in two passes: `SELECT` then `INSERT`.
#
# #### **The `movies` Table**

# %%
# %%sql
# -- Populate the movies table
# -- make sure the table is empty
# DELETE FROM movies;
#
# -- insert selected data
# INSERT INTO movies(title,rating)
# SELECT DISTINCT mtitle,rating
# FROM DATASET;
#
# -- There are 23 movies
# SELECT * FROM movies;
# Out:
#  * sqlite:///buan6510/data/MoviesTonight/MoviesTonight.db
# Done.
# Done.
# Done.
# [(1, 'Associate, The', 'PG-13'),
#  (2, 'Ghost & The Darkness, The', 'R'),
#  (3, 'Independence Day', 'PG-13'),
#  (4, 'D3: The Mighty Ducks', 'PG'),
#  (5, 'Dear God', None),
#  (6, 'First Wives Club, The', 'PG-13'),
#  (7, 'High School High', 'PG-13'),
#  (8, 'Larger Than Life', 'PG'),
#  (9, 'Mirror Has Two Faces, The', 'PG-13'),
#  (10, 'Ransom', 'R'),
#  (11, 'Sleepers', None),
#  (12, 'Space Jam', 'PG'),
#  (13, "Stephen King's Thinner", None),
#  (14, 'Michael Collins', 'R'),
#  (15, 'Romeo & Juliet', 'R'),
#  (16, 'Big Night', 'R'),
#  (17, 'Fly Away Home', 'PG'),
#  (18, 'Nutty Professor, The', 'PG-13'),
#  (19, 'Phenomenon', 'PG'),
#  (20, 'Set It Off', 'R'),
#  (21, 'Surviving Picasso', 'R'),
#  (22, 'Very Brady Sequel, A', 'PG-13'),
#  (23, 'That Thing You Do', 'PG')]

# %% [markdown]
# #### **The `artists` Table**

# %%
# %%sql
# -- Populate the artists table
# -- make sure the table is empty
# DELETE FROM artists;
#
# -- insert selected data
# INSERT INTO artists (name)
# SELECT DISTINCT cname
# FROM DATASET;
#
# -- There are 152 artists
# SELECT * FROM artists;
# Out:
#  * sqlite:///buan6510/data/MoviesTonight/MoviesTonight.db
# Done.
# Done.
# Done.
# [(1, 'Austin Pendleton', None),
#  (2, 'Bebe Neuwirth', None),
#  (3, 'Dianne Wiest', None),
#  (4, 'Eli Wallach', None),
#  (5, 'Kenny Kerr', None),
#  (6, 'Lainie Kazan', None),
#  (7, 'Tim Daly', None),
#  (8, 'Whoopi Goldberg', None),
#  (9, 'Donald Petrie', None),
#  (10, 'Bernard Hill', None),
#  (11, 'Brian McCardie', None),
#  (12, 'Emily Mortimer', None),
#  (13, 'Henry Cele', None),
#  (14, 'John Kani', None),
#  (15, 'Michael Douglas', None),
#  (16, 'Tom Wilkinson', None),
#  (17, 'Val Kilmer', None),
#  (18, 'Stephen Hopkins', None),
#  (19, 'Bill Pullman', None),
#  (20, 'Bill Smitrovich', None),
#  (21, 'Harvey Fierstein', None),
#  (22, 'Jeff Goldblum', None),
#  (23, 'Judd Hirsch', None),
#  (24, 'Margaret Colin', None),
#  (25, 'Mary McDonnell', None),
#  (26, 'Randy Quaid', None),
#  (27, 'Robert Loggia', None),
#  (28, 'Vivica Fox', None),
#  (29, 'Will Smith', None),
#  (30, 'Roland Emmerich', None),
#  (31, 'Emilio Estevez', None),
#  (32, 'Heidi Kling', None),
#  (33, 'Jeffrey Nordling', None),
#  (34, 'Joss Ackland', None),
#  (35, 'Rob Lieberman', None),
#  (36, 'Greg Kinnear', None),
#  (37, 'Hector Elizondo', None),
#  (38, 'Jon Seda', None),
#  (39, 'Laurie Metcalf', None),
#  (40, 'Maria Pitillo', None),
#  (41, 'Roscoe Lee Browne', None),
#  (42, 'Tim Conway', None),
#  (43, 'Garry Marshall', None),
#  (44, 'Bette Midler', None),
#  (45, 'Diane Keaton', None),
#  (46, 'Goldie Hawn', None),
#  (47, 'Hugh Wilson', None),
#  (48, 'and Louise Fletcher', None),
#  (49, 'Jon Lovitz', None),
#  (50, 'Mekhi Phifer', None),
#  (51, 'Tia Carrera', None),
#  (52, 'Hart Bochner', None),
#  (53, 'Bill Murray', None),
#  (54, 'Janeane Garofalo', None),
#  (55, 'Jeremy Piven', None),
#  (56, 'Keith David', None),
#  (57, 'Matthew McConaughey', None),
#  (58, 'Pat Hingle', None),
#  (59, 'Howard Franklin', None),
#  (60, 'Barbra Streisand', None),
#  (61, 'Jeff Bridges', None),
#  (62, 'Lauren Bacall', None),
#  (63, 'Pierce Brosnan', None),
#  (64, 'Delroy Lindo', None),
#  (65, 'Gary Sinese', None),
#  (66, 'Lili Taylor', None),
#  (67, 'Mel Gibson', None),
#  (68, 'Rene Russo', None),
#  (69, 'Ron Howard', None),
#  (70, 'Billy Crudup', None),
#  (71, 'Brad Pitt', None),
#  (72, 'Brad Renfro', None),
#  (73, 'Dustin Hoffman', None),
#  (74, 'Jason Patric', None),
#  (75, 'Joseph Perrino', None),
#  (76, 'Kevin Bacon', None),
#  (77, 'Minnie Driver', None),
#  (78, 'Robert De Niro', None),
#  (79, 'Ron Eldard', None),
#  (80, 'Terry Kinney', None),
#  (81, 'Vittorio Gassman', None),
#  (82, 'Barry Levinson', None),
#  (83, 'Michael Jordan', None),
#  (84, 'Theresa Randle', None),
#  (85, 'Wayne Knight', None),
#  (86, 'Joe Pytka', None),
#  (87, 'Joe Mantegna', None),
#  (88, 'Kari Wuhrer', None),
#  (89, 'Lucinda Jenney', None),
#  (90, 'Michael Constantine', None),
#  (91, 'Robert John Burke', None),
#  (92, 'Tom Holland', None),
#  (93, 'Aidan Quinn', None),
#  (94, 'Alan Rickman', None),
#  (95, 'Julia Roberts', None),
#  (96, 'Liam Neeson', None),
#  (97, 'Stephen Rea', None),
#  (98, 'Neil Jordan', None),
#  (99, 'Claire Danes', None),
#  (100, 'Diane Venora', None),
#  (101, 'John Leguizamo', None),
#  (102, 'Leonardo DiCaprio', None),
#  (103, 'Paul Rudd', None),
#  (104, 'Paul Sorvino', None),
#  (105, 'Baz Luhrmann', None),
#  (106, 'Campbell Scott', None),
#  (107, 'Ian Holm', None),
#  (108, 'Isabella Rossellini', None),
#  (109, 'Stanley Tucci', None),
#  (110, 'Tony Shalhoub', None),
#  (111, 'Anna Paquin', None),
#  (112, 'Dana Delany', None),
#  (113, 'Jeff Daniels', None),
#  (114, 'Carroll Ballard', None),
#  (115, 'Dave Chappelle', None),
#  (116, 'Eddie Murphy', None),
#  (117, 'Jada Pinkett', None),
#  (118, 'James Coburn', None),
#  (119, 'John Ales', None),
#  (120, 'Larry Miller', None),
#  (121, 'Tom Shadyac', None),
#  (122, 'Forest Whitaker', None),
#  (123, 'John Travolta', None),
#  (124, 'Kyra Sedgwick', None),
#  (125, 'Robert Duvall', None),
#  (126, 'Jon Turteltaub', None),
#  (127, 'Blair Underwood', None),
#  (128, 'John C. McGinley', None),
#  (129, 'Kimberly Elise', None),
#  (130, 'Queen Latifah', None),
#  (131, 'F. Gary Gray', None),
#  (132, 'Anthony Hopkins', None),
#  (133, 'Joan Plowright', None),
#  (134, 'Julianne Moore', None),
#  (135, 'Natascha McElhone', None),
#  (136, 'James Ivory', None),
#  (137, 'Christine Taylor', None),
#  (138, 'Christopher Daniel Barnes', None),
#  (139, 'Gary Cole', None),
#  (140, 'Henriette Mantel', None),
#  (141, 'Jennifer Elise Cox', None),
#  (142, 'Jesse Lee', None),
#  (143, 'Olivia Hack', None),
#  (144, 'Paul Sutera', None),
#  (145, 'Shelley Long', None),
#  (146, 'Tim Matheson', None),
#  (147, 'Arlene Sanford', None),
#  (148, 'Ethan Embry', None),
#  (149, 'Johnathon Schaech', None),
#  (150, 'Steve Zahn', None),
#  (151, 'Tom Everett Scott', None),
#  (152, 'Tom Hanks', None)]

# %% [markdown]
# ### **Populating the Weak Entity Tables**
# With the `theaters`, `movies`, and `artists` tables populated, including valid primary keys, we can now populate the `credits` and `shows` tables. However, there are two minor issues:
# - How to set the foreign keys, given that the primary keys of the first three tables are not in the  `DATASET` table.
# - The `ShowTime` values are nonstandard.
#
# We will address each of these issues as we populate the `credits` and `shows` tables one at a time.
#
# Note: The queries below were developed in several passes, just like with the first three tables.

# %% [markdown]
# #### **The `credits` Table**
#
# Since `movieID` and `artistID` do not exist in the `DATASET` table, we need to join in the `movies` and `artists` tables with the `DATASET` table. If we are willling to assume that artist names and movie titles are unique (at least in the data have on hand), we do it like this:

# %%
# %%sql
# -- Populate the credits table
# -- make sure the table is empty
# DELETE FROM credits;
#
# -- insert selected data
# DELETE FROM credits;
# INSERT INTO credits(credit_code,movieID,artistID)
# SELECT DISTINCT ccode, movieID, artistID
# FROM DATASET
#   JOIN movies ON (movies.title = DATASET.mtitle)  -- note: join on titles
#   JOIN artists ON (artists.name = DATASET.cname); -- note: join on names;
# Out:
#  * sqlite:///buan6510/data/MoviesTonight/MoviesTonight.db
# Done.
# Done.
# 161 rows affected.
# []

# %%
# %%sql
# SELECT * FROM credits LIMIT 10;
# Out:
#  * sqlite:///buan6510/data/MoviesTonight/MoviesTonight.db
# Done.
# [(1, 'A', 1, 1),
#  (2, 'A', 1, 2),
#  (3, 'A', 1, 3),
#  (4, 'A', 1, 4),
#  (5, 'A', 1, 5),
#  (6, 'A', 1, 6),
#  (7, 'A', 1, 7),
#  (8, 'A', 1, 8),
#  (9, 'D', 1, 9),
#  (10, 'A', 1, 1)]

# %% [markdown]
# **If we were going to join on the names and titles anyway, then why use surrogate keys?** To handle the data we have not seen yet. After this initial load with a small number of movies and artists, every subsequent insertion will need to use transaction control to keep the keys matched. That means adding one row at a time, not in bulk.
#
# #### **The `shows` Table**
# The `shows` table has the added complexity that the `ShowTime` column uses a nonstandard time format that is not supported by SQLite. We handle that with the somewhat ugly `CASE` expression below.

# %%
# %%sql
# -- Populate the shows table
# -- make sure the table is empty
# DELETE FROM shows;
#
# -- insert selected data
# INSERT INTO shows(movieID,theaterID,showtime)
# SELECT DISTINCT
#     movieID,
#     theaterID,
#     -- translates the showtime to ISO format
#     CASE
#       WHEN upper(ShowTime) LIKE '%AM' AND substr(ShowTime,1,instr(ShowTime,':')-1) = '12'
#           THEN printf('00:%2s', substr(ShowTime,instr(ShowTime,':')+1,2))
#       WHEN upper(ShowTime) LIKE '%PM' AND substr(ShowTime,1,instr(ShowTime,':')-1)+0 < '12'
#           THEN printf('%2i:%2s', substr(ShowTime,1,instr(ShowTime,':')-1) + 12,substr(ShowTime,instr(ShowTime,':')+1,2))
#       ELSE printf('%s:%2s', substr(ShowTime,1,instr(ShowTime,':')-1),substr(ShowTime,instr(ShowTime,':')+1,2))
#     END AS iso_time
# FROM DATASET
#       JOIN movies ON (movies.title = DATASET.mtitle)
#       JOIN theaters ON (theaters.name = DATASET.tname);
#
#
# SELECT * FROM shows LIMIT 10;
# Out:
#  * sqlite:///buan6510/data/MoviesTonight/MoviesTonight.db
# Done.
# Done.
# Done.
# [(1, '16:20', 1, 1),
#  (2, '19:20', 1, 1),
#  (3, '21:40', 1, 1),
#  (4, '17:10', 2, 1),
#  (5, '21:00', 2, 1),
#  (6, '21:05', 2, 1),
#  (7, '19:00', 3, 1),
#  (8, '16:40', 1, 2),
#  (9, '19:30', 1, 2),
#  (10, '14:30', 4, 2)]

# %% [markdown]
# **Details about the logic of the `CASE` expression are provided in the PRO TIPS section.**

# %% [markdown]
# ### **Kicking the Tires with a Few Queries**
#
# The following queries test whether:
# - We got the right number of rows in each table
# - The foreign keys match

# %%
# %%sql
# -- There should be 9 theaters
# SELECT count(*) FROM theaters;
# Out:
#  * sqlite:///buan6510/data/MoviesTonight/MoviesTonight.db
# Done.
# [(9,)]

# %%
# %%sql
# -- There should be 23 movies
# SELECT count(*) FROM movies;
# Out:
#  * sqlite:///buan6510/data/MoviesTonight/MoviesTonight.db
# Done.
# [(23,)]

# %%
# %%sql
# -- There should be 152 artists
# SELECT count(*) FROM artists;
# Out:
#  * sqlite:///buan6510/data/MoviesTonight/MoviesTonight.db
# Done.
# [(152,)]

# %%
# %%sql
# -- There should be 161 credits
# SELECT count(*) FROM credits;
# Out:
#  * sqlite:///buan6510/data/MoviesTonight/MoviesTonight.db
# Done.
# [(161,)]

# %%
# %%sql
# -- There should be 131 movies
# SELECT count(*) FROM shows;
# Out:
#  * sqlite:///buan6510/data/MoviesTonight/MoviesTonight.db
# Done.
# [(131,)]

# %%
# %%sql
# -- This query tries out artist --> credit --> movies
# SELECT name,credit_code
# FROM artists JOIN credits USING (artistID) JOIN movies USING (movieID)
# WHERE title = "Space Jam";
# Out:
#  * sqlite:///buan6510/data/MoviesTonight/MoviesTonight.db
# Done.
# [('Bill Murray', 'A'),
#  ('Michael Jordan', 'A'),
#  ('Theresa Randle', 'A'),
#  ('Wayne Knight', 'A'),
#  ('Joe Pytka', 'D')]

# %%
# %%sql
# -- This query tries out theaters --> shows --> movie
# SELECT name, showtime, title
# FROM theaters JOIN shows USING (theaterID) JOIN movies USING (movieID)
# WHERE title = "Space Jam";
# Out:
#  * sqlite:///buan6510/data/MoviesTonight/MoviesTonight.db
# Done.
# [('Cinema Star The Ultraplex 14', '17:00', 'Space Jam'),
#  ('Cinema Star The Ultraplex 14', '18:00', 'Space Jam'),
#  ('Cinema Star The Ultraplex 14', '19:15', 'Space Jam'),
#  ('Cinema Star The Ultraplex 14', '20:15', 'Space Jam'),
#  ('SOCAL Marketplace Cinema', '16:45', 'Space Jam'),
#  ('SOCAL Marketplace Cinema', '17:50', 'Space Jam'),
#  ('SOCAL Marketplace Cinema', '19:15', 'Space Jam'),
#  ('SOCAL Marketplace Cinema', '20:10', 'Space Jam'),
#  ('SOCAL Marketplace Cinema', '21:30', 'Space Jam'),
#  ('United Artists Riverside (Galleria) Tyler Mall', '17:25', 'Space Jam'),
#  ('United Artists Riverside (Galleria) Tyler Mall', '19:30', 'Space Jam'),
#  ('United Artists Riverside (Galleria) Tyler Mall', '21:35', 'Space Jam')]

# %%
# %%sql
# -- What shows are there after "22:00" (10pm)
# SELECT title AS movie, name AS theater, showtime
# FROM theaters JOIN shows USING (theaterID) JOIN movies USING (movieID)
# WHERE showtime > "22:00"   -- takes advantage of ISO format's natural lexicographic ordering
# ORDER BY showtime;
# Out:
#  * sqlite:///buan6510/data/MoviesTonight/MoviesTonight.db
# Done.
# [('Ghost & The Darkness, The', 'Pacific Inland Center', '22:05'),
#  ('Set It Off', 'United Artists Riverside Park Sierra', '22:05'),
#  ('Mirror Has Two Faces, The', 'United Artists Riverside Park Sierra', '22:20')]

# %% [markdown]
# ### **A few more queries just for fun (sort of)**
#
# Make sure you understand why each of these works. Each relies on a thorough understanding of advanced `SELECT` queries.

# %%
# %%sql
# -- Who appeared in more than one movie?
# SELECT name
# FROM movies JOIN credits USING (movieID) JOIN artists USING (artistID)
# GROUP BY artistID, name
# HAVING count(*) > 1;
# Out:
#  * sqlite:///buan6510/data/MoviesTonight/MoviesTonight.db
# Done.
# [('Vivica Fox',),
#  ('Rob Lieberman',),
#  ('Bill Murray',),
#  ('Barbra Streisand',),
#  ('Minnie Driver',),
#  ('Diane Venora',),
#  ('Campbell Scott',),
#  ('Stanley Tucci',),
#  ('Jada Pinkett',)]

# %%
# %%sql
# -- Who was an actor and director in the same movie?
# SELECT name, title
# FROM artists JOIN credits AS c1 USING (artistID) JOIN movies USING (movieID) JOIN credits AS c2 using (movieID,artistID)
# WHERE c1.credit_code = "A" and c2.credit_code = "D";
# Out:
#  * sqlite:///buan6510/data/MoviesTonight/MoviesTonight.db
# Done.
# [('Rob Lieberman', 'D3: The Mighty Ducks'),
#  ('Barbra Streisand', 'Mirror Has Two Faces, The'),
#  ('Campbell Scott', 'Big Night'),
#  ('Stanley Tucci', 'Big Night')]

# %%
# %%sql
# -- Who was an actor and director in the same movie?
# -- This time using aggregation instead of extra joins
# SELECT name, title
# FROM artists JOIN credits USING (artistID) JOIN movies USING (movieID)
# WHERE credit_code in ("A","D")
# GROUP BY artistID, movieID, name, title
# HAVING count(credit_code) > 1
# Out:
#  * sqlite:///buan6510/data/MoviesTonight/MoviesTonight.db
# Done.
# [('Rob Lieberman', 'D3: The Mighty Ducks'),
#  ('Barbra Streisand', 'Mirror Has Two Faces, The'),
#  ('Campbell Scott', 'Big Night'),
#  ('Stanley Tucci', 'Big Night')]

# %%
# %%sql
# -- Which actors costarred with Eli Wallach?
# SELECT a2.name
# FROM artists AS a1 JOIN credits AS c1 USING (artistID) JOIN credits AS c2 USING (movieID) JOIN artists AS a2 ON (c2.artistID = a2.artistID)
# WHERE a1.name = "Eli Wallach" AND c1.credit_code ='A' AND c2.credit_code ='A' AND a2.name <> "Eli Wallach";
# Out:
#  * sqlite:///buan6510/data/MoviesTonight/MoviesTonight.db
# Done.
# [('Austin Pendleton',),
#  ('Bebe Neuwirth',),
#  ('Dianne Wiest',),
#  ('Kenny Kerr',),
#  ('Lainie Kazan',),
#  ('Tim Daly',),
#  ('Whoopi Goldberg',)]

# %% [markdown]
# ### **A little cleanup before we go**
# Now that we are done with it, we should drop the `DATASET` table. It's an artifact of the ETL process and not intended to be used as data.

# %%
# %%sql
# DROP TABLE IF EXISTS DATASET;
# Out:
#  * sqlite:///buan6510/data/MoviesTonight/MoviesTonight.db
# Done.
# []

# %% [markdown]
# **Heads Up** Why did we use ALL_CAPS for the `DATASET` table name? Because we wanted it to stand out from the others.

# %% [markdown]
# ---
# ## **PRO TIPS: How to handle nonstandard data formats**
#
# **This is an somewhat advanced topic. Try to follow along but know that you will not be quizzed on it.**
#
# Sometimes the source data will be formatted in a way that is not compatible with your database design. While the correct answer is usually to handle it before loading into the database $-$ Python and pandas are designed just for this sort of thing $-$ we can handle some of this using SQL itself.
#
# We saw an example in the Movies Tonight case, where we had to use a `CASE` expression to translate nonstandard show times to work in SQLite, which does not have native support for DATETIME data. From the docs:
# > SQLite has no DATETIME datatype. Instead, dates and times can be stored in any of these ways:
# >- As a TEXT string in the ISO-8601 format. Example: '2018-04-02 12:13:46'.
# >- As an INTEGER number of seconds since 1970 (also known as "unix time").
# >- As a REAL value that is the fractional Julian day number.
# >
# >The [built-in date and time functions](https://sqlite.org/lang_datefunc.html) of SQLite understand date/times in all of the formats above, and can freely change between them. Which format you use, is entirely up to your application.
#
# We have time string data in TEXT format. However, our time strings are not in ISO-8601 format, which uses 24-hour military times instead of AM and PM. Thus, the time '2:00 PM' should be '14:00' in ISO format. Unfortunately, SQLite does not provide a built in function to do the conversion, so we will need to handle the translation ourselves using `CASE` expressions.
#
# The following shows the process used to develop the `CASE` expression for Movies Tonight.
#
# **Pass 1: Detecting AM/PM**
# Let's start with recognizing that 'AM' has different rules from 'PM':
# - We will be converting the `ShowTime` column from the `DATASET` table.
# - The `upper()` function converts everything to uppercase. We can use that eliminate uppercase vs lowercase bugs.
# - The `LIKE` comparator allows us to look for patterns in strings; '%PM' matches any number of characters followed by 'PM'.

# %%
# %%sql
# SELECT
#     ShowTime,
#     CASE
#       WHEN upper(ShowTime) LIKE '%PM' THEN 'it is PM'
#       ELSE 'it is AM'
#     END AS `AM or PM`
# FROM DATASET
# LIMIT 10;
# Out:
#  * sqlite:///buan6510/data/MoviesTonight/MoviesTonight.db
# Done.
# [('4:20 PM', 'it is PM'),
#  ('4:20 PM', 'it is PM'),
#  ('4:20 PM', 'it is PM'),
#  ('4:20 PM', 'it is PM'),
#  ('4:20 PM', 'it is PM'),
#  ('4:20 PM', 'it is PM'),
#  ('4:20 PM', 'it is PM'),
#  ('4:20 PM', 'it is PM'),
#  ('4:20 PM', 'it is PM'),
#  ('7:20 PM', 'it is PM')]

# %% [markdown]
# **Pass 2: Handling Hours and Minutes**
# Next we need to pick off the hour and minutes part of the time string. Since the hour part sometimes has one character and in other cases has two, we will need to take that into account in our code.
# - The `instr(X,Y)` function return the position of the first occurence of `Y` in the string `X`.
# - The `substr(X,Y,Z)` function returns the substring of `X`, starting at position `Y` with `Z` characters.
# - A `GROUP BY` clause was used to make sure that both 1 digit and 2 digit hours are represented.
# - SQLite automatically **coerces** numerical strings like "12" or "3.14" to equivalent numerical types when used in arithmetic expressions. So `"12"+12 = 24`.

# %%
# %%sql
# SELECT
#     min(ShowTime),
#     instr(ShowTime,':')-1 AS hour_digits,
#     substr(ShowTime,1,instr(ShowTime,':')-1) AS hours,
#     substr(ShowTime,1,instr(ShowTime,':')-1)+12 AS hours_plus_12,
#     substr(ShowTime,instr(ShowTime,':')+1,2) AS mins,
#     CASE
#       WHEN upper(ShowTime) LIKE '%PM' THEN 'it is PM'
#       ELSE 'it is AM'
#     END AS `AM or PM`
# FROM DATASET
# GROUP BY hour_digits, `AM or PM`
# LIMIT 10;
# Out:
#  * sqlite:///buan6510/data/MoviesTonight/MoviesTonight.db
# Done.
# [('2:30 PM', 1, '2', 14, '30', 'it is PM'),
#  ('10:05 PM', 2, '10', 22, '05', 'it is PM')]

# %% [markdown]
# **Pass 3: Putting it all together**
#
# We now have enough to create the full expression. There are three cases to handle:
# - '12:00 AM' - '12:59 AM': The hour is '00'.
# - '01:00 AM' - '11:59 AM': The hour is as given, padded to two characters if need.
# - '12:00 PM' - 11:59 PM': Add 12 to the hour.
#
# We can take the second case as the default and handle the other two separately. The final code is shown below.
# - The `printf()` function is used to "pretty print" text in a fixed format; it is a holdover from the original C function.
# - The expressions for `hour_digits`, etc., were used in the `CASE` expressions as needed.
# - There were no midnight shows or morning matinees but the `CASE` expression should work for those cases too.

# %%
# %%sql
# SELECT
#     ShowTime,
#     CASE
#       WHEN upper(ShowTime) LIKE '%AM' AND substr(ShowTime,1,instr(ShowTime,':')-1) = '12'
#           THEN printf('00:%2s', substr(ShowTime,instr(ShowTime,':')+1,2))
#       WHEN upper(ShowTime) LIKE '%PM' AND substr(ShowTime,1,instr(ShowTime,':')-1)+0 < '12'
#           THEN printf('%2i:%2s', substr(ShowTime,1,instr(ShowTime,':')-1) + 12,substr(ShowTime,instr(ShowTime,':')+1,2))
#       ELSE printf('%s:%2s', substr(ShowTime,1,instr(ShowTime,':')-1),substr(ShowTime,instr(ShowTime,':')+1,2))
#     END AS iso_time
# FROM DATASET
# GROUP BY ShowTime;
# Out:
#  * sqlite:///buan6510/data/MoviesTonight/MoviesTonight.db
# Done.
# [('10:05 PM', '22:05'),
#  ('10:20 PM', '22:20'),
#  ('2:30 PM', '14:30'),
#  ('3:50 PM', '15:50'),
#  ('4:00 PM', '16:00'),
#  ('4:10 PM', '16:10'),
#  ('4:15 PM', '16:15'),
#  ('4:20 PM', '16:20'),
#  ('4:25 PM', '16:25'),
#  ('4:30 PM', '16:30'),
#  ('4:40 PM', '16:40'),
#  ('4:45 PM', '16:45'),
#  ('4:50 PM', '16:50'),
#  ('5:00 PM', '17:00'),
#  ('5:10 PM', '17:10'),
#  ('5:15 PM', '17:15'),
#  ('5:20 PM', '17:20'),
#  ('5:25 PM', '17:25'),
#  ('5:30 PM', '17:30'),
#  ('5:45 PM', '17:45'),
#  ('5:50 PM', '17:50'),
#  ('6:00 PM', '18:00'),
#  ('6:10 PM', '18:10'),
#  ('6:15 PM', '18:15'),
#  ('6:20 PM', '18:20'),
#  ('6:30 PM', '18:30'),
#  ('6:40 PM', '18:40'),
#  ('6:45 PM', '18:45'),
#  ('6:50 PM', '18:50'),
#  ('7:00 PM', '19:00'),
#  ('7:10 PM', '19:10'),
#  ('7:15 PM', '19:15'),
#  ('7:20 PM', '19:20'),
#  ('7:30 PM', '19:30'),
#  ('7:40 PM', '19:40'),
#  ('7:45 PM', '19:45'),
#  ('8:00 PM', '20:00'),
#  ('8:05 PM', '20:05'),
#  ('8:10 PM', '20:10'),
#  ('8:15 PM', '20:15'),
#  ('8:20 PM', '20:20'),
#  ('8:30 PM', '20:30'),
#  ('8:40 PM', '20:40'),
#  ('8:45 PM', '20:45'),
#  ('9:00 PM', '21:00'),
#  ('9:05 PM', '21:05'),
#  ('9:10 PM', '21:10'),
#  ('9:15 PM', '21:15'),
#  ('9:25 PM', '21:25'),
#  ('9:30 PM', '21:30'),
#  ('9:35 PM', '21:35'),
#  ('9:40 PM', '21:40'),
#  ('9:45 PM', '21:45'),
#  ('9:50 PM', '21:50')]

# %% [markdown]
# ---
# ## **SQL AND BEYOND: Amazon Web Services RDS Hosting Service**
#
# As you work with larger and larger datasets, your needs will eventually outgrow what will fit in SQLite or perhaps even your laptop's drive. For that you will want to use one of the budget-priced cloud storage services. We explored Google Cloud Platform in Lesson 3. It's great for one table databases but sometimes you are going to want the full relational model. Now it's Amazon's turn.
#
# Launched in 2009, Amazon's RDS service is a very popular choice for cloud-based RDBMS hosting, used for everything from the biggest enterprise systems to the smallest hobby projects. It supports a variety of relational DBMS platforms (Oracle, SQL Server, PostgreSQL, MySQL, MariaDB, etc.), with automated handling of system backups, user access controls, data migration, etc. that would normally require a trained database administrator. It also has virtually unlimited scale, pricing out storage capacity and data access bandwidth at commodity prices.
#
# Here we will walk through a managed MySQL server instance in RDS's Free Tier, which is plenty capable for most analytical projects.

# %% [markdown]
# ### **AWS Free Tier**
# The AWS Free Tier is a great place to learn about how Amazon Web Services works. It takes a few minutes to get a account set up. Although a credit card is required, it is fairly easy to void being charged by avoiding "autoscaling" and similar options.
#
# ![AWS Free Tier](https://github.com/christopherhuntley/BUAN6510/raw/master/img/L8_AWS_Free_Tier.png)
#
# ### **RDS Instances**
# RDS is Amazon's database hosting service. A database server (DBMS) in the RDS cloud is called an **instance**. The RDS Free Tier supports many of the most popular database options. The storage capacity is 20 gigabytes, with another 20 gigabytes set aside for backups, which is plenty for most purposes.
#
# ![](https://github.com/christopherhuntley/BUAN6510/raw/master/img/L8_RDS_MySQL_Engine.png)
#
# ![RDS Instance](https://github.com/christopherhuntley/BUAN6510/raw/master/img/L8_AWS_Database_Instance.png)
#
# Once the instance is created and configured, we can add databases using standard SQL commands. Here we are using a linux mysql client to create the database. We could have just as easily used MySQL Workbench for Windows or MacOS. (See [here](https://github.com/christopherhuntley/BUAN6510/raw/master/img/L8_MySQL_Workbench.png).) It's all SQL from here.
#
# ![Create database](https://github.com/christopherhuntley/BUAN6510/raw/master/img/L8_AWS_SQL_Create_Database.png)
#
# Note: one server can host multiple databases. We just have to repeat the `CREATE DATABASE` command for each database.
#
# After a database is created, we can use SQL `CREATE USER` and `GRANT` statements to allow remote users (i.e., a Colab notebook) to access the data. In the example below, SQL is used to grant permission to students to run `SELECT` queries.
#
# ![Grant Permisions](https://github.com/christopherhuntley/BUAN6510/raw/master/img/L8_AWS_User_Access.png)
#
# ### **Connect from Colab**
# Connecting to the database from Colab is exactly like we have been doing already. However, if we want to run `CREATE`, `ADD`, etc. we will need to log in with a privileged user. In the connection below the 'datamanager' user is logged in using a password typed in interactively (with a little help from the `getpass()` utility). That keeps the password out of the notebook code, where it may leak to people who you really don't want rummaging through your databases. To be extra safe you may want to hide the username as well.
#
# > **Heads Up:** The queries below won't run without `datamanager` privileges. Look but don't touch.

# %%
# install the pymysql driver needed to connect to MySQL
# !pip install pymysql

# Import getpass, which silently asks for passwords
import getpass

# Load %%sql magic 
# %load_ext sql

pw = getpass.getpass("Password:")
connection_string = 'mysql+pymysql://datamanager:{PW}@buan6510demo.cuj5bhwwzkbm.us-east-2.rds.amazonaws.com/nba_play_log'.format(PW=pw)
# %sql $connection_string
# Out:
# Collecting pymysql
#   Downloading https://files.pythonhosted.org/packages/4f/52/a115fe175028b058df353c5a3d5290b71514a83f67078a6482cff24d6137/PyMySQL-1.0.2-py3-none-any.whl (43kB)
#      |████████████████████████████████| 51kB 3.1MB/s
# Installing collected packages: pymysql
# Successfully installed pymysql-1.0.2
# Password:··········
# 'Connected: datamanager@nba_play_log'

# %% [markdown]
# We are now able to modify the data in the tables as needed. However, the 'datamanager' user cannot drop the database or modify any table definitions.

# %% [markdown]
# ### **Create and Populate Tables from CSV Files**
#
# CSV is a very popular data format. It is easy to import and export in/out of a spreadsheet, the files are fairly compact, and everybody has seen them before. However, there are some drawbacks for relational data:
# - A CSV file can only contain one table
# - Data types have to be inferred (and software will sometimes get it wrong)
# - It has no support for keys of any sort
# - Not very convenient for binary data (BLOBs)
#
# In order to make CSV files work properly for loading data into a relational database, the tried and true method is to
# - Create the table schema first (with `CREATE TABLE`).
# - Import data into the database from csv file. This will create one or more tables that we will drop at the end. They are only needed to get the data into the database.
# - Use SQL DML (`INSERT` and `UPDATE`) to populate the tables in the schema. The DML would be executed, one table at a time, following the "strongest entity first" rule to avoid referential integrity violations. However, if you are 100% sure there will be no violations, then it is recommended to temporarily turn off [referential integrity checks when bulk-loading data](https://dev.mysql.com/doc/refman/8.0/en/optimizing-innodb-bulk-data-loading.html).
#
# ![Bulk Load Performance](https://github.com/christopherhuntley/BUAN6510/raw/master/img/L8_fk_check_off.png)
#
# We'll take these one step at a time, with a load of a full season of NBA PlayLog data.
#
# **1. Create Table Schema.**
# The first step is exactly like we have done before:
# ![Create Table Schema](https://github.com/christopherhuntley/BUAN6510/raw/master/img/L8_Create_Table_Schema.png)
#
# Note that the `DROP TABLE` statements are in the reverse order of the `CREATE TABLE` statements. That's once again to avoid referential integrity violations.
#
# > **Heads up**: This method of keeping the DDL separate from the data files has an added advantage. It allows us to migrate data from one DBMS to another, even when they have different SQL dialects. The CSV files (or `INSERT` statements) would be the same for any vendor. We just have to change the data types and other details in the DDL to fit the SQL dialect we are migrating to.
#
# **2. Load from CSV files.**
# The source data can be loaded into the database any number of ways. MySQL, for example has a `LOAD DATA` command that can [pull directly from a CSV file](https://dev.mysql.com/doc/refman/8.0/en/load-data.html). In the example below, pandas is used to load the data in a somewhat DBMS-agnostic way:
#
# ![pandas data load](https://github.com/christopherhuntley/BUAN6510/raw/master/img/L8_Load_From_Pandas.png)
#
# The data is loaded one year at a time, with one CSV file per database table (`teams_import`, `games_import`, etc.).
#
# > **Heads up:** We can also load the data from one huge CSV file (e.g., the `PlayLog` table we have already explored) and then parse it out to several normalized tables. However, there are performance issues that can lock up the server if the CSV file is big enough. That is actually the case here. It's faster and less problematic to do some work before uploading to the server.
#
# **3. DML to Populate Tables.**
# With the data already in the database, we can then use `INSERT INTO ... SELECT` statements to transfer the data to tables. The query below loads data into the `games` table. Notice that it requires a pair of joins to the `teams` table in order to look up `team_id` keys.
#
# ![DML Populate Tables](https://github.com/christopherhuntley/BUAN6510/raw/master/img/L8_DML_Populate_Tables.png)
#
# Each of these `INSERT` statements is a database transaction **which can fail** for any of a number of reasons:
# - Primary key or foreign key violation.
# - Uses up 100% of CPU, memory, or disk space.
#
# ![CPU Utlization](https://github.com/christopherhuntley/BUAN6510/raw/master/img/L8_CPU_Utlization.png)
#
# - Connection reset due to a timeout.
#
# ![Connection Reset](https://github.com/christopherhuntley/BUAN6510/raw/master/img/L8_MySQL_Connection_Reset.png)
#
# - ... so many more ...
#
# Behind the scenes, the DBMS is going to great lengths to monitor each tansaction to warn if things are going awry. The key stat below is the "undo log entries," which shows that 4.5 million rows of data would have to be rolled back if the query were to fail.
#
# ![Transaction Monitoring](https://github.com/christopherhuntley/BUAN6510/raw/master/img/L8_MySQL_Transaction_Monitoring.png)
#
# Average write performance was about 1500 rows per second. If that drops to 0, then the database may be in a deadlocked state. Breaking the deadlock requires rebooting the server and yes, there is some risk that the server won't reboot. That's what backups are for!
#
# ![Insert Performance](https://github.com/christopherhuntley/BUAN6510/raw/master/img/L8_MySQL_Insert_Performance.png)
#
# If rollback does occur, then expect the process to take a while. Reverting 4.2 millions rows of data is not easy, especially if the server does not have enough swap space and in-memory cache.
#
# ![](https://github.com/christopherhuntley/BUAN6510/raw/master/img/L8_MySQL_Transaction_Rollback.png)
#
#
# **4. Clean up.**
# After we done with the import data, we can just drop the tables.
#
# ![Clean Up Tables](https://github.com/christopherhuntley/BUAN6510/raw/master/img/L8_Clean_Up.png)
#
# ### **Working with Dump Files**
#
# If the data already has been loaded into a database we can create a dump (archive) file. The process varies, but for MySQL it's packaged as a [separate utility](https://dev.mysql.com/doc/refman/8.0/en/mysqldump.html), shown here in the MySQL Workbench app.
#
# ![MySQL Dumps from Workbench](https://github.com/christopherhuntley/BUAN6510/raw/master/img/L8_MySQL_Dump_Workbench.png)
#
# The resulting dump file includes lots of SQL DDL and DML code that has been tuned to load as quickly as possible without errors. It can be treated like any other file, except that it may be many, many gigabytes in size. The process of restoring from a backup is the reverse of the dump file export.
#
# ![Restore from MySQL dump file](https://github.com/christopherhuntley/BUAN6510/raw/master/img/L8_Restore_Workbench.png)
#
# > **Heads up:** Since the dump file is an editable SQL script, we can alter the DDL statements (datatypes, constraints, etc.) to suit a different DBMS. The SQL DML is standard and does not need (much) fiddling.

# %% [markdown]
# ### **Run a Few Queries**
# Generally we would never use ad hoc `SELECT` queries with a large transactional database like this one, which is designed to writing data in small transactions. Instead, we would keep a data warehouse, with tables that have been selectively denormalized to better fit the needs of data analysts,
# for that sort of thing. The data warehouse would extract and load data **in bulk** from this database, never one row at a time. (We will cover this common architectural design in Lessons 9 and 10.) Nonetheless, we can get surprisingly good `SELECT` query performance from even fairly complex queries.
#
# Here, for example, is a query that totals up the playing time for each player in the 2004-05 regular season and playoffs. A few complexities:
# - Four tables and three joins, with millions rows of data being accessed and cross-referenced
# - Grouping, with lots of subtotals tracks at once
# - Sorting by a group aggregate (minutes)
#
# Total query time is 51 seconds, which not exactly instantaneous but good enough for the occasional query.

# %%
# %%sql
# SELECT team_code,players.name,sum(elapsed)/60 as minutes
# FROM players JOIN lineups USING (player_id) JOIN play_segments USING (play_seg_id) JOIN teams ON (players.team_id = teams.team_id)
# WHERE teams.team_year = 2005
# GROUP BY player_id, players.name, team_code
# ORDER BY minutes DESC;
# Out:
#  * mysql+pymysql://datamanager:***@buan6510demo.cuj5bhwwzkbm.us-east-2.rds.amazonaws.com/nba_play_log
# 526 rows affected.
# [('DET', 'Tayshaun Prince', Decimal('3987.1833')),
#  ('DET', 'Richard Hamilton', Decimal('3943.3000')),
#  ('DET', 'Chauncey Billups', Decimal('3795.4000')),
#  ('PHX', 'Shawn Marion', Decimal('3781.0667')),
#  ('WAS', 'Gilbert Arenas', Decimal('3729.7000')),
#  ('SAS', 'Tony Parker', Decimal('3602.1333')),
#  ('PHX', 'Joe Johnson', Decimal('3597.6167')),
#  ('DET', 'Ben Wallace', Decimal('3588.0833')),
#  ('MIA', 'Dwyane Wade', Decimal('3554.6000')),
#  ('DAL', 'Dirk Nowitzki', Decimal('3548.9000')),
#  ('SEA', 'Ray Allen', Decimal('3501.1333')),
#  ('HOU', 'Tracy McGrady', Decimal('3490.2167')),
#  ('PHX', "Amar'e Stoudemire", Decimal('3485.8167')),
#  ('SAS', 'Bruce Bowen', Decimal('3444.7667')),
#  ('DET', 'Rasheed Wallace', Decimal('3440.7833')),
#  ('MIA', 'Eddie Jones', Decimal('3436.4333')),
#  ('PHX', 'Quentin Richardson', Decimal('3410.6667')),
#  ('CLE', 'LeBron James', Decimal('3383.5833')),
#  ('PHI', 'Allen Iverson', Decimal('3334.4667')),
#  ('NYK', 'Stephon Marbury', Decimal('3299.6000')),
#  ('SAC', 'Mike Bibby', Decimal('3247.8833')),
#  ('MIA', 'Udonis Haslem', Decimal('3218.3000')),
#  ('BOS', 'Paul Pierce', Decimal('3214.9333')),
#  ('PHX', 'Steve Nash', Decimal('3178.6333')),
#  ('MIA', 'Damon Jones', Decimal('3089.3833')),
#  ('MIN', 'Kevin Garnett', Decimal('3077.5500')),
#  ('SAS', 'Tim Duncan', Decimal('3071.7333')),
#  ('DEN', 'Andre Miller', Decimal('3038.8500')),
#  ('SEA', 'Rashard Lewis', Decimal('3013.3000')),
#  ('CHI', 'Kirk Hinrich', Decimal('3012.4833')),
#  ('LAC', 'Elton Brand', Decimal('3011.0500')),
#  ('WAS', 'Antawn Jamison', Decimal('2987.7833')),
#  ('SAS', 'Manu Ginobili', Decimal('2982.3667')),
#  ('SEA', 'Luke Ridnour', Decimal('2952.1000')),
#  ('TOR', 'Chris Bosh', Decimal('2938.4667')),
#  ('ORL', 'Steve Francis', Decimal('2936.6500')),
#  ('MIA', "Shaquille O'Neal", Decimal('2935.0167')),
#  ('LAL', 'Chucky Atkins', Decimal('2915.8167')),
#  ('BOS', 'Ricky Davis', Decimal('2897.6167')),
#  ('MIL', 'Desmond Mason', Decimal('2873.1667')),
#  ('DAL', 'Jason Terry', Decimal('2870.3000')),
#  ('NYK', 'Kurt Thomas', Decimal('2860.3833')),
#  ('MIL', 'Michael Redd', Decimal('2852.8167')),
#  ('DAL', 'Michael Finley', Decimal('2842.9833')),
#  ('DAL', 'Josh Howard', Decimal('2842.7833')),
#  ('NOH', 'P.J. Brown', Decimal('2827.8333')),
#  ('LAC', 'Bobby Simmons', Decimal('2816.0833')),
#  ('PHI', 'Andre Iguodala', Decimal('2799.8000')),
#  ('DEN', 'Carmelo Anthony', Decimal('2789.8500')),
#  ('BOS', 'Gary Payton', Decimal('2765.2167')),
#  ('WAS', 'Larry Hughes', Decimal('2760.0500')),
#  ('LAL', 'Caron Butler', Decimal('2738.5500')),
#  ('PHI', 'Kyle Korver', Decimal('2738.4833')),
#  ('POR', 'Damon Stoudamire', Decimal('2730.4333')),
#  ('GSW', 'Jason Richardson', Decimal('2713.2167')),
#  ('SAC', 'Peja Stojakovic', Decimal('2699.6333')),
#  ('LAL', 'Kobe Bryant', Decimal('2691.4333')),
#  ('NYK', 'Jamal Crawford', Decimal('2684.5333')),
#  ('HOU', 'Yao Ming', Decimal('2682.9167')),
#  ('TOR', 'Jalen Rose', Decimal('2668.5833')),
#  ('TOR', 'Rafer Alston', Decimal('2654.5833')),
#  ('MEM', 'Shane Battier', Decimal('2651.1667')),
#  ('ORL', 'Dwight Howard', Decimal('2650.5167')),
#  ('CLE', 'Jeff McInnis', Decimal('2650.1167')),
#  ('NJN', 'Jason Collins', Decimal('2636.3833')),
#  ('CLE', 'Zydrunas Ilgauskas', Decimal('2615.4333')),
#  ('CHA', 'Emeka Okafor', Decimal('2592.7000')),
#  ('NJN', 'Jason Kidd', Decimal('2590.7500')),
#  ('UTA', 'Matt Harpring', Decimal('2584.6500')),
#  ('GSW', 'Mike Dunleavy', Decimal('2573.4667')),
#  ('IND', 'Reggie Miller', Decimal('2549.5833')),
#  ('ATL', 'Al Harrington', Decimal('2546.1333')),
#  ('MIN', 'Wally Szczerbiak', Decimal('2528.0667')),
#  ('CLE', 'Drew Gooden', Decimal('2524.5167')),
#  ('IND', 'Fred Jones', Decimal('2468.6167')),
#  ('TOR', 'Morris Peterson', Decimal('2458.3833')),
#  ('LAC', 'Corey Maggette', Decimal('2446.2500')),
#  ('DEN', 'Kenyon Martin', Decimal('2442.3833')),
#  ('MIN', 'Latrell Sprewell', Decimal('2411.5000')),
#  ('MEM', 'Mike Miller', Decimal('2401.8500')),
#  ('GSW', 'Troy Murphy', Decimal('2387.5500')),
#  ('MEM', 'Lorenzen Wright', Decimal('2379.7500')),
#  ('ATL', 'Josh Childress', Decimal('2372.3833')),
#  ('NJN', 'Vince Carter', Decimal('2371.2833')),
#  ('CHI', 'Tyson Chandler', Decimal('2361.5667')),
#  ('BOS', 'Raef LaFrentz', Decimal('2356.1333')),
#  ('SEA', 'Antonio Daniels', Decimal('2355.7000')),
#  ('CHI', 'Chris Duhon', Decimal('2340.6833')),
#  ('LAL', 'Lamar Odom', Decimal('2323.6500')),
#  ('DEN', 'Earl Boykins', Decimal('2320.4667')),
#  ('UTA', 'Mehmet Okur', Decimal('2319.0833')),
#  ('ORL', 'Grant Hill', Decimal('2308.7833')),
#  ('CHA', 'Primoz Brezec', Decimal('2288.1833')),
#  ('MIL', 'Joe Smith', Decimal('2274.6333')),
#  ('SAS', 'Brent Barry', Decimal('2274.6167')),
#  ('MIL', 'Mo Williams', Decimal('2274.0667')),
#  ('IND', 'Stephen Jackson', Decimal('2266.9833')),
#  ('DET', 'Antonio McDyess', Decimal('2261.3833')),
#  ('WAS', 'Jared Jeffries', Decimal('2253.4500')),
#  ('SAC', 'Brad Miller', Decimal('2231.1500')),
#  ('GSW', 'Derek Fisher', Decimal('2221.2667')),
#  ('DEN', 'Marcus Camby', Decimal('2207.5500')),
#  ('CHI', 'Ben Gordon', Decimal('2162.7667')),
#  ('WAS', 'Brendan Haywood', Decimal('2161.5000')),
#  ('BOS', 'Mark Blount', Decimal('2157.8667')),
#  ('CHA', 'Gerald Wallace', Decimal('2156.5833')),
#  ('ATL', 'Antoine Walker', Decimal('2131.2333')),
#  ('HOU', 'David Wesley', Decimal('2127.3333')),
#  ('HOU', 'Bob Sura', Decimal('2103.1000')),
#  ('NJN', 'Nenad Krstic', Decimal('2098.2000')),
#  ('SEA', 'Reggie Evans', Decimal('2089.3333')),
#  ('CHI', 'Andres Nocioni', Decimal('2084.4500')),
#  ('MEM', 'Jason Williams', Decimal('2071.0500')),
#  ('NOH', 'Dan Dickau', Decimal('2062.4667')),
#  ('IND', 'Anthony Johnson', Decimal('2061.3333')),
#  ('ATL', 'Josh Smith', Decimal('2050.2000')),
#  ('MIN', 'Trenton Hassell', Decimal('2049.4667')),
#  ('SAS', 'Robert Horry', Decimal('2037.4500')),
#  ('IND', "Jermaine O'Neal", Decimal('2025.7167')),
#  ('NOH', 'Lee Nailon', Decimal('2024.8667')),
#  ('CHI', 'Antonio Davis', Decimal('2006.7833')),
#  ('PHI', 'Marc Jackson', Decimal('1992.6833')),
#  ('DAL', 'Jerry Stackhouse', Decimal('1989.9500')),
#  ('SEA', 'Vladimir Radmanovic', Decimal('1984.8000')),
#  ('CHA', 'Brevin Knight', Decimal('1953.0833')),
#  ('POR', 'Ruben Patterson', Decimal('1945.8500')),
#  ('PHI', 'Samuel Dalembert', Decimal('1945.4667')),
#  ('NYK', 'Tim Thomas', Decimal('1940.5833')),
#  ('LAC', 'Rick Brunson', Decimal('1935.1333')),
#  ('MEM', 'Pau Gasol', Decimal('1917.8833')),
#  ('SAS', 'Rasho Nesterovic', Decimal('1890.9667')),
#  ('ORL', 'Tony Battie', Decimal('1889.5833')),
#  ('CHA', 'Jason Hart', Decimal('1887.2000')),
#  ('DAL', 'Erick Dampier', Decimal('1886.4833')),
#  ('MEM', 'Earl Watson', Decimal('1881.6833')),
#  ('LAL', 'Chris Mihm', Decimal('1878.2667')),
#  ('IND', 'Austin Croshere', Decimal('1872.4333')),
#  ('NOH', 'J.R. Smith', Decimal('1859.1000')),
#  ('POR', 'Joel Przybilla', Decimal('1858.2333')),
#  ('IND', 'Jeff Foster', Decimal('1854.9333')),
#  ('POR', 'Shareef Abdur-Rahim', Decimal('1843.7167')),
#  ('CLE', 'Eric Snow', Decimal('1841.3000')),
#  ('LAL', 'Jumaine Jones', Decimal('1838.1167')),
#  ('CLE', 'Ira Newble', Decimal('1825.8667')),
#  ('SAC', 'Cuttino Mobley', Decimal('1825.7500')),
#  ('CHI', 'Eddy Curry', Decimal('1817.1500')),
#  ('UTA', 'Raja Bell', Decimal('1788.1000')),
#  ('CHA', 'Keith Bogans', Decimal('1787.1667')),
#  ('UTA', 'Carlos Boozer', Decimal('1780.7500')),
#  ('MIL', 'Dan Gadzuric', Decimal('1779.1833')),
#  ('ORL', 'Hedo Turkoglu', Decimal('1733.7333')),
#  ('MIN', 'Troy Hudson', Decimal('1717.4167')),
#  ('SAC', 'Darius Songaila', Decimal('1713.7167')),
#  ('GSW', 'Adonal Foyle', Decimal('1695.6000')),
#  ('POR', 'Theo Ratliff', Decimal('1691.7833')),
#  ('POR', 'Darius Miles', Decimal('1674.2000')),
#  ('SAC', 'Chris Webber', Decimal('1669.3667')),
#  ('CHI', 'Luol Deng', Decimal('1666.0667')),
#  ('UTA', 'Gordan Giricek', Decimal('1661.3667')),
#  ('LAC', 'Marko Jaric', Decimal('1656.1833')),
#  ('CHA', 'Melvin Ely', Decimal('1648.9167')),
#  ('LAC', 'Quinton Ross', Decimal('1641.7333')),
#  ('HOU', 'Juwan Howard', Decimal('1621.4667')),
#  ('LAC', 'Chris Kaman', Decimal('1619.8333')),
#  ('DEN', 'Greg Buckner', Decimal('1619.4833')),
#  ('SEA', 'Jerome James', Decimal('1618.7167')),
#  ('SEA', 'Nick Collison', Decimal('1615.1000')),
#  ('TOR', 'Donyell Marshall', Decimal('1606.5667')),
#  ('ORL', 'Jameer Nelson', Decimal('1600.7333')),
#  ('POR', 'Nick Van Exel', Decimal('1592.5167')),
#  ('POR', 'Zach Randolph', Decimal('1567.3833')),
#  ('WAS', 'Jarvis Hayes', Decimal('1562.3333')),
#  ('DAL', 'Marquis Daniels', Decimal('1552.8667')),
#  ('NYK', 'Nazr Mohammed', Decimal('1532.3667')),
#  ('ATL', 'Tyronn Lue', Decimal('1528.8667')),
#  ('IND', 'Jamaal Tinsley', Decimal('1519.5833')),
#  ('MEM', 'Brian Cardinal', Decimal('1517.7500')),
#  ('NJN', 'Travis Best', Decimal('1517.2667')),
#  ('TOR', 'Matt Bonner', Decimal('1511.3167')),
#  ('GSW', 'Speedy Claxton', Decimal('1505.4500')),
#  ('NJN', 'Richard Jefferson', Decimal('1504.8667')),
#  ('MEM', 'Bonzi Wells', Decimal('1504.6833')),
#  ('MIN', 'Sam Cassell', Decimal('1503.5000')),
#  ('ORL', 'Kelvin Cato', Decimal('1501.4333')),
#  ('TOR', 'Milt Palacio', Decimal('1500.7500')),
#  ('IND', 'James Jones', Decimal('1491.8500')),
#  ('NYK', 'Michael Sweetney', Decimal('1491.6667')),
#  ('MIN', 'Eddie Griffin', Decimal('1483.1833')),
#  ('CHA', 'Jason Kapono', Decimal('1481.3833')),
#  ('DET', 'Lindsey Hunter', Decimal('1478.6833')),
#  ('PHX', 'Jim Jackson', Decimal('1471.5000')),
#  ('MEM', 'James Posey', Decimal('1467.6667')),
#  ('ATL', 'Predrag Drobnjak', Decimal('1438.1500')),
#  ('MIA', 'Keyon Dooling', Decimal('1437.8000')),
#  ('UTA', 'Howard Eisley', Decimal('1428.2167')),
#  ('DEN', 'Nene', Decimal('1415.8167')),
#  ('WAS', 'Michael Ruffin', Decimal('1414.3000')),
#  ('HOU', 'Jon Barry', Decimal('1411.1167')),
#  ('NOH', 'Chris Andersen', Decimal('1407.7500')),
#  ('MIL', 'Zaza Pachulia', Decimal('1394.2167')),
#  ('SAS', 'Beno Udrih', Decimal('1390.2333')),
#  ('NJN', 'Jacque Vaughn', Decimal('1384.6667')),
#  ('CHI', 'Othella Harrington', Decimal('1384.0333')),
#  ('UTA', 'Keith McLeod', Decimal('1381.4167')),
#  ('MIA', 'Rasual Butler', Decimal('1380.9333')),
#  ('NYK', 'Trevor Ariza', Decimal('1380.9167')),
#  ('UTA', 'Andrei Kirilenko', Decimal('1353.3333')),
#  ('ATL', 'Tony Delk', Decimal('1348.6500')),
#  ('GSW', 'Mickael Pietrus', Decimal('1339.9500')),
#  ('POR', 'Sebastian Telfair', Decimal('1330.3833')),
#  ('CLE', 'Robert Traylor', Decimal('1328.9667')),
#  ('BOS', 'Tony Allen', Decimal('1324.3667')),
#  ('MEM', 'Stromile Swift', Decimal('1321.4167')),
#  ('HOU', 'Dikembe Mutombo', Decimal('1319.8500')),
#  ('PHI', 'Kenny Thomas', Decimal('1319.0333')),
#  ('NJN', 'Rodney Buford', Decimal('1309.6500')),
#  ('DEN', 'DerMarr Johnson', Decimal('1294.3167')),
#  ('SAS', 'Devin Brown', Decimal('1285.4000')),
#  ('DAL', 'Alan Henderson', Decimal('1277.0667')),
#  ('WAS', 'Juan Dixon', Decimal('1271.8167')),
#  ('PHX', 'Steven Hunter', Decimal('1263.3000')),
#  ('MIA', 'Shandon Anderson', Decimal('1250.0167')),
#  ('MIN', 'Fred Hoiberg', Decimal('1245.7333')),
#  ('SAC', 'Maurice Evans', Decimal('1244.6833')),
#  ('DAL', 'Devin Harris', Decimal('1239.9833')),
#  ('BOS', 'Marcus Banks', Decimal('1236.9333')),
#  ('MIA', 'Michael Doleac', Decimal('1232.5667')),
#  ('NJN', 'Brian Scalabrine', Decimal('1224.2500')),
#  ('MIN', 'Michael Olowokandi', Decimal('1217.4333')),
#  ('NYK', 'Jerome Williams', Decimal('1210.3500')),
#  ('PHX', 'Leandro Barbosa', Decimal('1201.3333')),
#  ('POR', 'Derek Anderson', Decimal('1200.8500')),
#  ('PHI', 'Aaron McKie', Decimal('1193.8333')),
#  ('ATL', 'Boris Diaw', Decimal('1193.4333')),
#  ('LAC', 'Mikki Moore', Decimal('1166.5667')),
#  ('BOS', 'Al Jefferson', Decimal('1162.8500')),
#  ('SEA', 'Danny Fortson', Decimal('1152.4000')),
#  ('MIL', 'Mike James', Decimal('1142.1167')),
#  ('NOH', 'Bostjan Nachbar', Decimal('1137.1333')),
#  ('LAL', 'Brian Grant', Decimal('1132.0667')),
#  ('CLE', 'Lucious Harris', Decimal('1128.0667')),
#  ('PHI', 'Willie Green', Decimal('1123.0000')),
#  ('WAS', 'Etan Thomas', Decimal('1107.9500')),
#  ('BOS', 'Jiri Welsch', Decimal('1104.4500')),
#  ('GSW', 'Clifford Robinson', Decimal('1094.7667')),
#  ('MIL', 'Toni Kukoc', Decimal('1088.5500')),
#  ('LAL', 'Brian Cook', Decimal('1080.3167')),
#  ('ORL', 'DeShawn Stevenson', Decimal('1077.6667')),
#  ('BOS', 'Antoine Walker', Decimal('1066.5667')),
#  ('LAL', 'Tierre Brown', Decimal('1050.8833')),
#  ('HOU', 'Scott Padgett', Decimal('1046.4833')),
#  ('IND', 'Dale Davis', Decimal('1042.5333')),
#  ('PHI', 'Corliss Williamson', Decimal('1041.8333')),
#  ('IND', 'Eddie Gill', Decimal('1038.2333')),
#  ('NOH', 'Casey Jacobsen', Decimal('1037.7333')),
#  ('DEN', 'Bryon Russell', Decimal('1033.0167')),
#  ('LAC', 'Chris Wilcox', Decimal('1014.2333')),
#  ('MIL', 'Erick Strickland', Decimal('1013.1667')),
#  ('HOU', 'Jim Jackson', Decimal('995.6833')),
#  ('SAC', 'Doug Christie', Decimal('992.2167')),
#  ('GSW', 'Baron Davis', Decimal('990.0167')),
#  ('PHI', 'John Salmons', Decimal('980.6500')),
#  ('WAS', 'Kwame Brown', Decimal('967.7333')),
#  ('SAS', 'Nazr Mohammed', Decimal('947.3667')),
#  ('DEN', 'Francisco Elson', Decimal('946.3000')),
#  ('SAC', 'Kenny Thomas', Decimal('945.5000')),
#  ('GSW', 'Calbert Cheaney', Decimal('945.3667')),
#  ('SEA', 'Ronald Murray', Decimal('943.5167')),
#  ('UTA', 'Jarron Collins', Decimal('942.8667')),
#  ('ATL', 'Jason Collier', Decimal('941.2333')),
#  ('NOH', 'David Wesley', Decimal('930.5000')),
#  ('NOH', 'George Lynch', Decimal('929.4833')),
#  ('ORL', 'Pat Garrity', Decimal('928.8500')),
#  ('LAC', 'Zeljko Rebraca', Decimal('928.4167')),
#  ('MIL', 'Marcus Fizer', Decimal('912.0000')),
#  ('HOU', 'Maurice Taylor', Decimal('909.7500')),
#  ('CHI', 'Eric Piatkowski', Decimal('905.6500')),
#  ('UTA', 'Kirk Snyder', Decimal('901.4000')),
#  ('DAL', 'Shawn Bradley', Decimal('892.5167')),
#  ('TOR', 'Lamond Murray', Decimal('889.7833')),
#  ('IND', 'Scot Pollard', Decimal('887.7167')),
#  ('NYK', 'Anfernee Hardaway', Decimal('885.4000')),
#  ('NOH', 'Rodney Rogers', Decimal('882.7333')),
#  ('CHA', 'Kareem Rush', Decimal('877.4000')),
#  ('MIA', 'Christian Laettner', Decimal('871.4333')),
#  ('UTA', 'Kris Humphries', Decimal('870.0000')),
#  ('CLE', 'Anderson Varejao', Decimal('868.9833')),
#  ('HOU', 'Mike James', Decimal('867.6167')),
#  ('CLE', 'Sasha Pavlovic', Decimal('866.6667')),
#  ('SAS', 'Malik Rose', Decimal('866.1667')),
#  ('UTA', 'Curtis Borchardt', Decimal('856.4833')),
#  ('PHI', 'Chris Webber', Decimal('853.4333')),
#  ('LAC', 'Shaun Livingston', Decimal('820.6000')),
#  ('DET', 'Carlos Arroyo', Decimal('820.3833')),
#  ('MIL', 'Keith Van Horn', Decimal('819.6500')),
#  ('ATL', 'Royal Ivey', Decimal('814.2000')),
#  ('POR', 'Travis Outlaw', Decimal('792.5167')),
#  ('PHX', 'Casey Jacobsen', Decimal('762.7000')),
#  ('LAL', 'Luke Walton', Decimal('762.5333')),
#  ('ATL', 'Tom Gugliotta', Decimal('748.0167')),
#  ('CHI', 'Adrian Griffin', Decimal('746.6667')),
#  ('IND', 'David Harrison', Decimal('743.5833')),
#  ('UTA', 'Carlos Arroyo', Decimal('742.8333')),
#  ('NJN', 'Eric Williams', Decimal('739.0833')),
#  ('ATL', 'Obinna Ekezie', Decimal('729.2833')),
#  ('NOH', 'Jamaal Magloire', Decimal('723.6833')),
#  ('TOR', 'Rafael Araujo', Decimal('722.9500')),
#  ('SAS', 'Tony Massenburg', Decimal('720.3833')),
#  ('DAL', 'Keith Van Horn', Decimal('717.2500')),
#  ('ATL', 'Kenny Anderson', Decimal('716.6333')),
#  ('MIN', 'Anthony Carter', Decimal('715.4167')),
#  ('MEM', 'Dahntay Jones', Decimal('715.0333')),
#  ('SAC', 'Brian Skinner', Decimal('712.4667')),
#  ('ORL', 'Cuttino Mobley', Decimal('709.2667')),
#  ('SAC', 'Matt Barnes', Decimal('704.0500')),
#  ('HOU', 'Ryan Bowen', Decimal('700.9000')),
#  ('TOR', 'Loren Woods', Decimal('683.4667')),
#  ('WAS', 'Steve Blake', Decimal('664.6667')),
#  ('SEA', 'Damien Wilkins', Decimal('656.6167')),
#  ('NOH', 'Jackson Vroman', Decimal('649.5333')),
#  ('ORL', 'Stacey Augmon', Decimal('649.3000')),
#  ('CHA', 'Steven Smith', Decimal('645.0833')),
#  ('NJN', 'Clifford Robinson', Decimal('643.7167')),
#  ('NJN', 'Jabari Smith', Decimal('643.2333')),
#  ('DAL', 'Darrell Armstrong', Decimal('633.2500')),
#  ('SAC', 'Bobby Jackson', Decimal('618.8000')),
#  ('NYK', 'Malik Rose', Decimal('616.5000')),
#  ('GSW', 'Eduardo Najera', Decimal('608.2000')),
#  ('BOS', 'Delonte West', Decimal('605.7167')),
#  ('DEN', 'Eduardo Najera', Decimal('586.4500')),
#  ('NOH', 'Baron Davis', Decimal('583.1000')),
#  ('SAC', 'Greg Ostertag', Decimal('582.7500')),
#  ('MIN', 'Mark Madsen', Decimal('582.3833')),
#  ('GSW', 'Dale Davis', Decimal('580.1333')),
#  ('TOR', 'Vince Carter', Decimal('574.6000')),
#  ('WAS', 'Anthony Peeler', Decimal('566.5000')),
#  ('BOS', 'Kendrick Perkins', Decimal('566.4833')),
#  ('SAC', 'Eddie House', Decimal('559.9167')),
#  ('TOR', 'Eric Williams', Decimal('557.0000')),
#  ('NOH', 'David West', Decimal('548.6333')),
#  ('NYK', 'Allan Houston', Decimal('544.3167')),
#  ('NOH', 'Junior Harrington', Decimal('541.9333')),
#  ('DEN', 'Rodney White', Decimal('531.7167')),
#  ('POR', 'Viktor Khryapa', Decimal('529.1333')),
#  ('ORL', 'Doug Christie', Decimal('528.6333')),
#  ('BOS', 'Walter McCarty', Decimal('526.3333')),
#  ('HOU', 'Clar. Weatherspoon', Decimal('524.2167')),
#  ('CHI', 'Jannero Pargo', Decimal('523.0167')),
#  ('MIN', 'John Thomas', Decimal('520.8333')),
#  ('UTA', 'Raul Lopez', Decimal('516.7000')),
#  ('CHA', 'Theron Smith', Decimal('515.2167')),
#  ('DEN', 'Wesley Person', Decimal('514.4333')),
#  ('NJN', 'Zoran Planinic', Decimal('513.5833')),
#  ('PHI', 'Rodney Rogers', Decimal('511.0833')),
#  ('SAC', 'Corliss Williamson', Decimal('500.9500')),
#  ('DET', 'Ronald Dupree', Decimal('493.5833')),
#  ('POR', 'Richie Frahm', Decimal('490.5167')),
#  ('MIA', 'Alonzo Mourning', Decimal('489.9333')),
#  ('HOU', 'Tyronn Lue', Decimal('480.7500')),
#  ('MIL', 'Anthony Goldwire', Decimal('477.9000')),
#  ('GSW', 'Zarko Cabarkapa', Decimal('464.5833')),
#  ('DET', 'Carlos Delfino', Decimal('462.0333')),
#  ('NJN', 'Alonzo Mourning', Decimal('461.4000')),
#  ('SAC', 'Kevin Martin', Decimal('448.7000')),
#  ('NOH', 'Matt Freije', Decimal('436.7000')),
#  ('NYK', 'Maurice Taylor', Decimal('433.2667')),
#  ('ATL', 'Donta Smith', Decimal('432.3833')),
#  ('CHA', 'Matt Carroll', Decimal('432.2833')),
#  ('WAS', 'Laron Profit', Decimal('425.0667')),
#  ('LAC', 'Lionel Chalmers', Decimal('424.7833')),
#  ('LAL', 'Slava Medvedenko', Decimal('421.1167')),
#  ('NOH', 'Darrell Armstrong', Decimal('416.1500')),
#  ('PHX', 'Walter McCarty', Decimal('411.3667')),
#  ('MIN', 'Ervin Johnson', Decimal('408.6167')),
#  ('DET', 'Elden Campbell', Decimal('402.3500')),
#  ('LAL', 'Sasha Vujacic', Decimal('402.2167')),
#  ('GSW', 'Andris Biedrins', Decimal('382.0833')),
#  ('NOH', 'Speedy Claxton', Decimal('380.4000')),
#  ('SEA', 'Vitaly Potapenko', Decimal('371.3667')),
#  ('NJN', 'Ron Mercer', Decimal('370.6333')),
#  ('HOU', 'Charlie Ward', Decimal('358.8667')),
#  ('PHX', 'Jake Voskuhl', Decimal('357.1667')),
#  ('ORL', 'Mario Kasun', Decimal('352.0333')),
#  ('NJN', 'Billy Thomas', Decimal('351.7667')),
#  ('ATL', 'Kevin Willis', Decimal('345.5000')),
#  ('CHA', 'Bernard Robinson', Decimal('324.1833')),
#  ('CHA', 'Jamal Sampson', Decimal('322.8167')),
#  ('PHI', 'Josh Davis', Decimal('319.1167')),
#  ('NYK', 'Moochie Norris', Decimal('312.8167')),
#  ('MEM', 'Ryan Humphrey', Decimal('310.5500')),
#  ('HOU', 'Andre Barrett', Decimal('309.4000')),
#  ('LAL', 'Devean George', Decimal('306.4167')),
#  ('CLE', 'DeSagana Diop', Decimal('305.1833')),
#  ('UTA', 'Ben Handlogten', Decimal('294.8500')),
#  ('CHA', 'Eddie House', Decimal('294.8000')),
#  ('IND', 'Metta World Peace', Decimal('290.2500')),
#  ('MIL', 'Kendall Gill', Decimal('283.5167')),
#  ('MEM', 'Jake Tsakalidis', Decimal('278.1500')),
#  ('ATL', 'Jon Barry', Decimal('275.9167')),
#  ('DET', 'Darvin Ham', Decimal('274.1167')),
#  ('SAS', 'Glenn Robinson', Decimal('272.5000')),
#  ('DET', 'Darko Milicic', Decimal('271.8500')),
#  ('CHA', 'Malik Allen', Decimal('267.2500')),
#  ('SAS', 'Mike Wilks', Decimal('266.2833')),
#  ('DAL', 'Calvin Booth', Decimal('262.1000')),
#  ('NOH', 'Maciej Lampe', Decimal('260.5000')),
#  ('TOR', 'Pape Sow', Decimal('251.6000')),
#  ('MIA', 'Malik Allen', Decimal('247.6833')),
#  ('IND', 'Michael Curry', Decimal('244.5167')),
#  ('PHI', 'Brian Skinner', Decimal('244.3667')),
#  ('LAC', 'Kerry Kittles', Decimal('242.9833')),
#  ('SAS', 'Sean Marks', Decimal('241.1667')),
#  ('UTA', 'Randy Livingston', Decimal('229.8500')),
#  ('NYK', 'Jermaine Jackson', Decimal('224.4000')),
#  ('MEM', 'Antonio Burks', Decimal('219.8667')),
#  ('PHX', 'Bo Outlaw', Decimal('217.2167')),
#  ('BOS', 'Tom Gugliotta', Decimal('215.3667')),
#  ('ORL', 'Brandon Hunter', Decimal('211.8333')),
#  ('MIA', 'Wesley Person', Decimal('206.9667')),
#  ('HOU', 'Bostjan Nachbar', Decimal('202.6333')),
#  ('CHA', 'Cory Alexander', Decimal('197.6167')),
#  ('HOU', 'Rod Strickland', Decimal('197.2833')),
#  ('CLE', 'Jiri Welsch', Decimal('191.1500')),
#  ('NYK', 'Vin Baker', Decimal('190.4167')),
#  ('MIL', 'Calvin Booth', Decimal('190.1833')),
#  ('LAC', 'Darrick Martin', Decimal('189.5500')),
#  ('NYK', 'Jamison Brewer', Decimal('179.3833')),
#  ('ORL', 'Andre Barrett', Decimal('167.8000')),
#  ('TOR', 'Aaron Williams', Decimal('163.8833')),
#  ('MIL', 'Zendon Hamilton', Decimal('160.9333')),
#  ('DEN', 'Nikoloz Tskitishvili', Decimal('154.0667')),
#  ('CLE', 'Scott Williams', Decimal('152.1500')),
#  ('WAS', 'Damone Brown', Decimal('151.2333')),
#  ('NJN', 'Aaron Williams', Decimal('147.6667')),
#  ('NOH', 'Alex Garcia', Decimal('145.6000')),
#  ('GSW', 'Rodney White', Decimal('145.1000')),
#  ('PHI', 'Kevin Ollie', Decimal('143.3667')),
#  ('ATL', 'Michael Stewart', Decimal('142.8500')),
#  ('CHI', 'Jared Reiner', Decimal('138.3167')),
#  ('WAS', 'Samaki Walker', Decimal('136.3500')),
#  ('BOS', 'Justin Reed', Decimal('134.9667')),
#  ('IND', 'John Edwards', Decimal('133.5833')),
#  ('LAL', 'Vlade Divac', Decimal('131.0333')),
#  ('CHA', 'Jahidi White', Decimal('130.5000')),
#  ('UTA', 'Aleksandar Radojevic', Decimal('128.1000')),
#  ('GSW', 'Ansu Sesay', Decimal('127.8500')),
#  ('PHX', 'Maciej Lampe', Decimal('118.9833')),
#  ('MIA', 'Steven Smith', Decimal('115.8500')),
#  ('ORL', 'Mark Jones', Decimal('115.1667')),
#  ('NOH', 'Corsley Edwards', Decimal('110.0333')),
#  ('POR', 'James Thomas', Decimal('108.6167')),
#  ('DET', 'Smush Parker', Decimal('106.2333')),
#  ('IND', 'Marcus Haislip', Decimal('105.4833')),
#  ('MIL', 'Daniel Santiago', Decimal('104.9667')),
#  ('CLE', 'Dajuan Wagner', Decimal('101.8000')),
#  ('HOU', 'Reece Gaines', Decimal('101.2000')),
#  ('POR', 'Ha Seung-Jin', Decimal('100.1500')),
#  ('DET', 'Horace Jenkins', Decimal('97.9500')),
#  ('LAL', 'Kareem Rush', Decimal('92.9500')),
#  ('IND', 'Jonathan Bender', Decimal('92.3667')),
#  ('MIA', 'Wang Zhi-zhi', Decimal('89.5167')),
#  ('ATL', 'Jelani McCoy', Decimal('85.7667')),
#  ('MIL', 'Reece Gaines', Decimal('79.0667')),
#  ('CHA', 'Tamar Slay', Decimal('77.6333')),
#  ('TOR', 'Omar Cook', Decimal('73.3000')),
#  ('LAC', "Mamadou N'diaye", Decimal('73.2167')),
#  ('IND', 'Britton Johnsen', Decimal('72.8667')),
#  ('SAC', 'Erik Daniels', Decimal('70.7833')),
#  ('GSW', 'Luis Flores', Decimal('70.4333')),
#  ('CHI', 'Frank Williams', Decimal('69.9167')),
#  ('SEA', 'Robert Swift', Decimal('69.8667')),
#  ('TOR', 'Jerome Moiso', Decimal('69.7667')),
#  ('NYK', 'Bruno Sundov', Decimal('68.4833')),
#  ('SAS', 'Dion Glover', Decimal('66.2333')),
#  ('SEA', 'Mateen Cleaves', Decimal('60.1167')),
#  ('GSW', 'Nikoloz Tskitishvili', Decimal('59.9667')),
#  ('DAL', 'DJ Mbenga', Decimal('56.6000')),
#  ('DEN', 'Voshon Lenard', Decimal('56.5000')),
#  ('PHX', 'Jackson Vroman', Decimal('56.1500')),
#  ('NJN', 'Kaniel Dickens', Decimal('54.1000')),
#  ('MIN', 'Ndudi Ebi', Decimal('53.9000')),
#  ('DET', 'Anthony Goldwire', Decimal('52.3500')),
#  ('ORL', 'Michael Bradley', Decimal('51.9000')),
#  ('ORL', 'Andrew DeClercq', Decimal('50.4167')),
#  ('PHI', 'Kedrick Brown', Decimal('50.4167')),
#  ('CHI', 'Lawrence Funderburke', Decimal('49.6500')),
#  ('DET', 'Derrick Coleman', Decimal('49.3333')),
#  ('NJN', 'Elden Campbell', Decimal('47.8167')),
#  ('SAC', 'Michael Bradley', Decimal('46.6833')),
#  ('IND', 'Tremaine Fowlkes', Decimal('46.0833')),
#  ('HOU', 'Moochie Norris', Decimal('45.7000')),
#  ('CLE', 'Luke Jackson', Decimal('43.0833')),
#  ('MIL', 'Eddie House', Decimal('39.3167')),
#  ('NOH', 'Lonny Baxter', Decimal('34.1333')),
#  ('PHX', 'Smush Parker', Decimal('33.4333')),
#  ('PHX', 'Paul Shirley', Decimal('29.5667')),
#  ('CLE', 'Jerome Moiso', Decimal('28.1333')),
#  ('MIA', 'Dorell Wright', Decimal('28.1000')),
#  ('MIA', 'Qyntel Woods', Decimal('27.3333')),
#  ('NJN', 'Awvee Storey', Decimal('27.0000')),
#  ('LAC', 'Kenny Anderson', Decimal('26.2667')),
#  ('MEM', 'Andre Emmett', Decimal('25.9000')),
#  ('DEN', 'Mark Pope', Decimal('25.0333')),
#  ('HOU', 'Torraye Braggs', Decimal('22.2667')),
#  ('NYK', 'Shandon Anderson', Decimal('20.2333')),
#  ('NJN', 'Jerome Moiso', Decimal('20.0167')),
#  ('WAS', 'Peter Ramos', Decimal('19.5667')),
#  ('POR', 'Maurice Baker', Decimal('18.3333')),
#  ('PHX', 'Yuta Tabuse', Decimal('17.2833')),
#  ('NJN', 'Donnell Harvey', Decimal('16.3000')),
#  ('POR', 'Geno Carlisle', Decimal('15.3833')),
#  ('SAS', 'Linton Johnson', Decimal('15.2333')),
#  ('DAL', 'Dan Dickau', Decimal('14.4167')),
#  ('HOU', 'Vin Baker', Decimal('13.4667')),
#  ('LAC', 'Kirk Penney', Decimal('12.1000')),
#  ('LAL', 'Tony Bobbitt', Decimal('11.9333')),
#  ('PHX', 'Zarko Cabarkapa', Decimal('11.2000')),
#  ('SEA', 'Ibrahim Kutluay', Decimal('10.9333')),
#  ('ATL', 'Anthony Miller', Decimal('9.7000')),
#  ('PHI', 'Michael Bradley', Decimal('8.9667')),
#  ('DAL', 'Pavel Podkolzin', Decimal('7.5500')),
#  ('ATL', 'James Thomas', Decimal('4.4667')),
#  ('NYK', 'Jackie Butler', Decimal('4.3833')),
#  ('DEN', 'Luis Flores', Decimal('3.7667')),
#  ('HOU', 'Brandin Knight', Decimal('2.7833')),
#  ('LAC', 'Maurice Baker', Decimal('1.1000'))]

# %% [markdown]
# Let's see how much data that really was:

# %%
# %%sql
# SELECT
#   (SELECT count(*) FROM players JOIN teams USING (team_id) WHERE team_year=2005) AS players,
#   (SELECT count(*) FROM lineups JOIN play_segments USING (play_seg_id) JOIN games USING (game_id) WHERE game_year=2005) AS lineups,
#   (SELECT count(*) FROM play_segments JOIN games USING (game_id) where game_year = 2005) AS plays,
#   (SELECT count(*) FROM teams WHERE team_year = 2005) AS teams
# Out:
#  * mysql+pymysql://datamanager:***@buan6510demo.cuj5bhwwzkbm.us-east-2.rds.amazonaws.com/nba_play_log
# 1 rows affected.
# [(526, 5944039, 594457, 30)]

# %% [markdown]
# > **Heads up**: If we had just one cross join in there, the query would have quickly outstripped the server's memory and storage capacity. 5944039 x 594457 is a *very* large number. [Also, note that the number of lineups *should* be  10x the number of plays (because there are 10 players on the court at a time). However, there were some plays in the original play log with less than 10 players due to injuries, ejections, and data collection errors. It might be interesting to study those to see what happened.]

# %% [markdown]
# ---
# ## **Congratulations! You've made it to the end of Lesson 8.**
#
# That's a wrap on SQL DML. Just be sure to study for Quiz 4.

# %% [markdown]
# ## **On your way out ... Be sure to save your work**.
# In Google Drive, drag this notebook file into your `BUAN6510` folder so you can find it next time.
